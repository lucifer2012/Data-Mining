# %%
import csv

# %%
whole = []
with open('hospitalLevels.csv', 'rb') as csvfile:
    reader = csv.reader(csvfile)
    for row in reader:
        whole.append(row)

# %%
for i in range(len(whole[0])):
    print i, whole[0][i]
# Out:
# 0 Provider Id
# 1 Provider Name
# 2 Provider Street Address
# 3 Provider City
# 4 Provider State
# 5 Provider Zip Code
# 6 WtedCharge
# 7 povertyrate
# 8 Weighted Poverty Rate(radius= 50 miles)

# %%
print len(wtedcharge)
print len(poverty)
print len(wtedpoverty)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-92aa90bd924d> in <module>()
# ----> 1 print len(wtedcharge)
#       2 print len(poverty)
#       3 print len(wtedpoverty)
#
# NameError: name 'wtedcharge' is not defined

# %%
wtedcharge = []
poverty = []
wtedpoverty = []
for i in range(1, len(whole)):
    if whole[i][7] != 'what':
        wtedcharge.append([float(whole[i][6])])
        poverty.append(float(whole[i][7]))
        wtedpoverty.append(float(whole[i][8]))

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model

regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(wtedcharge, wtedpoverty)

# The coefficients
#print('Coefficients: \n', regr.coef_)
# The mean squared error
print "regr.coef is",regr.coef_
print "intercept is", regr.predict(0)
print "parameters are", regr.get_params()
print("Mean squared error: %.2f"
       % np.mean((regr.predict(wtedcharge) - wtedpoverty) ** 2))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % regr.score(wtedcharge, wtedpoverty))

# Plot outputs
plt.scatter(wtedcharge, wtedpoverty,  color='black')
plt.plot(wtedcharge, regr.predict(wtedcharge), color='blue',
         linewidth=3)


plt.xticks()
plt.yticks()
plt.title("WtdCharge vs WtdPovertyRate")
plt.xlabel("Weighted Charge")
plt.ylabel("Weighted Poverty Rate")
plt.xlim([0, 5])
plt.ylim([0, 60])
plt.show()
print "Mean squared error: 34.06, Variance score: 0.01"
# Out:
# regr.coef is [-1.18464452]
# intercept is [ 17.36898397]
# parameters are {'copy_X': True, 'normalize': False, 'n_jobs': 1, 'fit_intercept': True}
# Mean squared error: 21.47
# Variance score: 0.02
# Mean squared error: 34.06, Variance score: 0.01

# %%
# Load the diabetes dataset
# diabetes = datasets.load_diabetes()


# Use only one feature
#diabetes_X = diabetes.data[:, np.newaxis, 2]

# Split the data into training/testing sets
# diabetes_X_train = diabetes_X[:-20]
# diabetes_X_test = diabetes_X[-20:]

# Split the targets into training/testing sets
# diabetes_y_train = diabetes.target[:-20]
# diabetes_y_test = diabetes.target[-20:]

# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(wtedcharge, wtedpoverty)

# The coefficients
#print('Coefficients: \n', regr.coef_)
# The mean squared error
print("Mean squared error: %.2f"
       % np.mean((regr.predict(wtedcharge) - wtedpoverty) ** 2))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % regr.score(wtedcharge, wtedpoverty))

# Plot outputs
plt.scatter(wtedcharge, wtedpoverty,  color='black')
plt.plot(wtedcharge, regr.predict(wtedcharge), color='blue',
         linewidth=3)

plt.xticks()
plt.yticks()
plt.title("WtdCharge vs WtdPovertyRate")
plt.xlabel("Weighted Charge")
plt.ylabel("Weighted Poverty Rate")
plt.show()
print "Mean squared error: 21.47, Variance score: 0.02"
# Out:
# Mean squared error: 21.47
# Variance score: 0.02
# Mean squared error: 21.47, Variance score: 0.02

# %%
west = ['AK', 'CA', 'CO', 'HI', 'ID', 'MT', 'NV', 'OR', 'UT', 'WA', 'WY']
midwest = ['ND', 'SD', 'NE', 'KS', 'MN', 'IA', 'MO', 'WI', 'IL', 'IN', 'MI', 'OH']
southwest = ['NM', 'AZ', 'OK', 'TX', 'SC', 'NC']
southeast = ['AR', 'LA', 'MS', 'AL', 'TN', 'KY', 'GA', 'FL', 'WV', 'VA']
northeast = ['CT', 'DE', 'ME', 'MD', 'MA', 'NH', 'NH', 'NY', 'PA', 'RI', 'VT', 'NJ', 'DC']

# %%
print len(west)+len(midwest)+len(southeast)+len(southwest)+len(northeast)
# Out:
# 52

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
# Out:
# /Users/Chen/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
#%matplotlib inline

# %%
# use wtd
charge_west = []
poverty_west = []
for i in range(1, len(whole)):
    if whole[i][7] != 'what' and whole[i][4] in west:
        charge_west.append([float(whole[i][6])])
        poverty_west.append(float(whole[i][8]))

regr = linear_model.LinearRegression()
regr.fit(charge_west, poverty_west)
print("Mean squared error: %.2f"
       % np.mean((regr.predict(charge_west) - poverty_west) ** 2))
print('Variance score: %.2f' % regr.score(charge_west, poverty_west))
print "regr.coef is",regr.coef_
print "intercept is", regr.predict(0)
coef_west = regr.coef_
intcept_west = regr.predict(0)
plt.scatter(charge_west, poverty_west,  color='black')
plt.plot(charge_west, regr.predict(charge_west), color='blue',
         linewidth=3)
plt.xticks()
plt.yticks()
plt.xlim([0, 5])
plt.ylim([0, 40])
plt.title("West of United States")
plt.xlabel("Weighted Charge")
plt.ylabel("Weighted Poverty Rate")
plt.show()
#print "Mean squared error: 21.47, Variance score: 0.02"
# Out:
# Mean squared error: 12.92
# Variance score: 0.00
# regr.coef is [-0.14084908]
# intercept is [ 15.41143907]

# %%
charge_midwest = []
poverty_midwest = []
for i in range(1, len(whole)):
    if whole[i][7] != 'what' and whole[i][4] in midwest:
        charge_midwest.append([float(whole[i][6])])
        poverty_midwest.append(float(whole[i][8]))

regr = linear_model.LinearRegression()
regr.fit(charge_midwest, poverty_midwest)
print("Mean squared error: %.2f"
       % np.mean((regr.predict(charge_midwest) - poverty_midwest) ** 2))
print('Variance score: %.2f' % regr.score(charge_midwest, poverty_midwest))
print "regr.coef is",regr.coef_
print "intercept is", regr.predict(0)
coef_midwest = regr.coef_
intcept_midwest = regr.predict(0)
plt.scatter(charge_midwest, poverty_midwest,  color='black')
plt.plot(charge_midwest, regr.predict(charge_midwest), color='blue',
         linewidth=3)
plt.xticks()
plt.yticks()
plt.xlim([0, 5])
plt.ylim([0, 40])
plt.title("Midwest of United States")
plt.xlabel("Weighted Charge")
plt.ylabel("Weighted Poverty Rate")
plt.show()
# Out:
# Mean squared error: 6.86
# Variance score: 0.05
# regr.coef is [-2.23404223]
# intercept is [ 15.57793654]

# %%
charge_southwest = []
poverty_southwest = []
for i in range(1, len(whole)):
    if whole[i][7] != 'what' and whole[i][4] in southwest:
        charge_southwest.append([float(whole[i][6])])
        poverty_southwest.append(float(whole[i][8]))

regr = linear_model.LinearRegression()
regr.fit(charge_southwest, poverty_southwest)
print("Mean squared error: %.2f"
       % np.mean((regr.predict(charge_southwest) - poverty_southwest) ** 2))
print('Variance score: %.2f' % regr.score(charge_southwest, poverty_southwest))
plt.scatter(charge_southwest, poverty_southwest,  color='black')
plt.plot(charge_southwest, regr.predict(charge_southwest), color='blue',
         linewidth=3)
plt.xticks()
plt.yticks()
plt.xlim([0, 5])
plt.ylim([0, 40])
plt.title("Southwest of United States")
plt.xlabel("Weighted Charge")
plt.ylabel("Weighted Poverty Rate")
plt.show()
# Out:
# Mean squared error: 20.83
# Variance score: 0.01

# %%
charge_southeast = []
poverty_southeast = []
for i in range(1, len(whole)):
    if whole[i][7] != 'what' and whole[i][4] in southeast:
        charge_southeast.append([float(whole[i][6])])
        poverty_southeast.append(float(whole[i][8]))

regr = linear_model.LinearRegression()
regr.fit(charge_southeast, poverty_southeast)
print("Mean squared error: %.2f"
       % np.mean((regr.predict(charge_southeast) - poverty_southeast) ** 2))
print('Variance score: %.2f' % regr.score(charge_southeast, poverty_southeast))
print "regr.coef is",regr.coef_
print "intercept is", regr.predict(0)
coef_southeast = regr.coef_
intcept_southeast = regr.predict(0)
plt.scatter(charge_southeast, poverty_southeast,  color='black')
plt.plot(charge_southeast, regr.predict(charge_southeast), color='blue',
         linewidth=3)
plt.xticks()
plt.yticks()
plt.xlim([0, 5])
plt.ylim([0, 40])
plt.title("Southeast of United States")
plt.xlabel("Weighted Charge")
plt.ylabel("Weighted Poverty Rate")
plt.show()
# Out:
# Mean squared error: 16.93
# Variance score: 0.07
# regr.coef is [-2.89902033]
# intercept is [ 22.59039627]

# %%
charge_northeast = []
poverty_northeast = []
for i in range(1, len(whole)):
    if whole[i][7] != 'what' and whole[i][4] in northeast:
        charge_northeast.append([float(whole[i][6])])
        poverty_northeast.append(float(whole[i][8]))

regr = linear_model.LinearRegression()
regr.fit(charge_northeast, poverty_northeast)
print("Mean squared error: %.2f"
       % np.mean((regr.predict(charge_northeast) - poverty_northeast) ** 2))
print('Variance score: %.2f' % regr.score(charge_northeast, poverty_northeast))
plt.scatter(charge_northeast, poverty_northeast,  color='black')
plt.plot(charge_northeast, regr.predict(charge_northeast), color='blue',
         linewidth=3)
plt.xticks()
plt.yticks()
plt.xlim([0, 5])
plt.ylim([0, 40])
plt.title("Northeast of United States")
plt.xlabel("Weighted Charge")
plt.ylabel("Weighted Poverty Rate")
plt.show()
# Out:
# Mean squared error: 4.05
# Variance score: 0.04

# %%
# west
# south east
# midwest
print coef_midwest[0], intcept_midwest[0]
print coef_southeast[0], intcept_southeast[0]
print coef_west[0], intcept_west[0]
# Out:
# -2.23404223408 15.5779365408
# -2.89902032589 22.5903962668
# -0.140849081983 15.4114390696

# %%
allstates = west + midwest + southwest + southeast + northeast

# %%
import math

# %%
midwest_group = []
southeast_group = []
west_group = []

# %%
westdata = dict()
midwestdata = dict()
southeastdata = dict()
counters = dict()
for state in allstates:
    westdata[state] = 0
    midwestdata[state] = 0
    southeastdata[state] = 0
    #counters[state] = 0
for row in whole:
    if row[4] in westdata.keys():
        #counters[row[4]] += 1
        westdata[row[4]] += abs(float(row[6]) * coef_west[0] - float(row[8]) + intcept_west[0]) / math.sqrt(float(coef_west[0]) ** 2 + 1)
        midwestdata[row[4]] += abs(float(row[6]) * coef_midwest[0] - float(row[8]) + intcept_midwest[0]) / math.sqrt(float(coef_midwest[0]) ** 2 + 1)
        southeastdata[row[4]] += abs(float(row[6]) * coef_southeast[0] - float(row[8]) + intcept_southeast[0]) / math.sqrt(float(coef_southeast[0]) ** 2 + 1)

# %%
print southeastdata['WA'], westdata['WA'], midwestdata['WA']
# Out:
# 87.116188339 121.59926664 42.3851606556

# %%
for key in westdata.keys():
    tmp = [westdata[key], midwestdata[key], southeastdata[key]]
    flag = tmp.index(min(tmp))
    if flag == 0:
        west_group.append(key)
    elif flag == 1:
        midwest_group.append(key)
    else:
        southeast_group.append(key)

# %%
print southeast_group
print west_group
print midwest_group
print len(southeast_group) + len(west_group) + len(midwest_group)
# Out:
# ['WV', 'FL', 'NM', 'TX', 'LA', 'NC', 'TN', 'CA', 'NV', 'AL', 'AR', 'GA', 'AZ', 'ID', 'OK', 'MS', 'SC', 'KY', 'OR']
# []
# ['WA', 'DE', 'DC', 'WI', 'HI', 'WY', 'NH', 'NJ', 'ND', 'NE', 'NY', 'PA', 'VA', 'CO', 'AK', 'VT', 'IL', 'IN', 'IA', 'MA', 'CT', 'ME', 'MD', 'OH', 'UT', 'MO', 'MN', 'MI', 'RI', 'KS', 'MT', 'SD']
# 51

# %%
charge_southeast_group = []
poverty_southeast_group = []
for i in range(1, len(whole)):
    if whole[i][7] != 'what' and whole[i][4] in southeast_group:
        charge_southeast_group.append([float(whole[i][6])])
        poverty_southeast_group.append(float(whole[i][8]))

regr = linear_model.LinearRegression()
regr.fit(charge_southeast_group, poverty_southeast_group)
print("Mean squared error: %.2f"
       % np.mean((regr.predict(charge_southeast_group) - poverty_southeast_group) ** 2))
print('Variance score: %.2f' % regr.score(charge_southeast_group, poverty_southeast_group))
print "regr.coef is",regr.coef_
print "intercept is", regr.predict(0)
plt.scatter(charge_southeast_group, poverty_southeast_group,  color='black')
plt.plot(charge_southeast_group, regr.predict(charge_southeast_group), color='blue',
         linewidth=3)
plt.xticks()
plt.yticks()
plt.xlim([0, 5])
plt.ylim([0, 40])
plt.title("Southeast part of United States")
plt.xlabel("Weighted Charge")
plt.ylabel("Weighted Poverty Rate")
plt.show()
# Out:
# Mean squared error: 17.08
# Variance score: 0.11
# regr.coef is [-2.77999598]
# intercept is [ 21.73022435]

# %%
charge_midwest_group = []
poverty_midwest_group = []
for i in range(1, len(whole)):
    if whole[i][7] != 'what' and whole[i][4] in midwest_group:
        charge_midwest_group.append([float(whole[i][6])])
        poverty_midwest_group.append(float(whole[i][8]))

regr = linear_model.LinearRegression()
regr.fit(charge_midwest_group, poverty_midwest_group)
print("Mean squared error: %.2f"
       % np.mean((regr.predict(charge_midwest_group) - poverty_midwest_group) ** 2))
print('Variance score: %.2f' % regr.score(charge_midwest_group, poverty_midwest_group))
print "regr.coef is",regr.coef_
print "intercept is", regr.predict(0)
plt.scatter(charge_midwest_group, poverty_midwest_group,  color='black')
plt.plot(charge_midwest_group, regr.predict(charge_midwest_group), color='blue',
         linewidth=3)
plt.xticks()
plt.yticks()
plt.xlim([0, 5])
plt.ylim([0, 40])
plt.title("Midwest part of United States")
plt.xlabel("Weighted Charge")
plt.ylabel("Weighted Poverty Rate")
plt.show()
# Out:
# Mean squared error: 7.73
# Variance score: 0.05
# regr.coef is [-1.44333148]
# intercept is [ 14.54932486]

# %%
def kmeans():
#     whole = []
#     with open('hospitalLevels.csv', 'rb') as csvfile:
#         reader = csv.reader(csvfile)
#         for row in reader:
#             whole.append(row)
    west = ['AK', 'CA', 'CO', 'HI', 'ID', 'MT', 'NV', 'OR', 'UT', 'WA', 'WY']
    midwest = ['ND', 'SD', 'NE', 'KS', 'MN', 'IA', 'MO', 'WI', 'IL', 'IN', 'MI', 'OH']
    southwest = ['NM', 'AZ', 'OK', 'TX']
    southeast = ['AR', 'LA', 'MS', 'AL', 'TN', 'KY', 'GA', 'FL', 'WV', 'VA', ]
    northeast = ['CT', 'DE', 'ME', 'MD', 'MA', 'NH', 'NH', 'NY', 'PA', 'RI', 'VT']
    west.sort()
    midwest.sort()
    southwest.sort()
    southeast.sort()
    northeast.sort()
    west_coef, west_incept = 0, 0
    midwest_coef, midwest_incept = 0, 0
    southeast_coef, southeast_incept = 0, 0
    northeast_coef, northeast_incept = 0, 0
    southwest_coef, southwest_incept = 0, 0
    flag = 1
    while(flag):
        westdata = dict()
        midwestdata = dict()
        southeastdata = dict()
        northeastdata = dict()
        southwestdata = dict()
        allstates = west + midwest + southwest + southeast + northeast
        for state in allstates:
            westdata[state] = 0
            midwestdata[state] = 0
            southeastdata[state] = 0
            northeastdata[state] = 0
            southwestdata[state] = 0
        if len(west) != 0:
            west_coef, west_incept = regs(west)
#             for row in whole:
#                 if row[4] in westdata.keys():
#                     westdata[row[4]] += abs(float(row[6]) * west_coef - float(row[8]) + west_incept) / math.sqrt(float(west_coef) ** 2 + 1)
        if len(midwest) != 0:
            midwest_coef, midwest_incept = regs(midwest)
#             for row in whole:
#                 if row[4] in westdata.keys():
#                     midwestdata[row[4]] += abs(float(row[6]) * midwest_coef - float(row[8]) + midwest_incept) / math.sqrt(float(midwest_coef) ** 2 + 1)
        if len(southeast) != 0:
            southeast_coef, southeast_incept = regs(southeast)
#             for row in whole:
#                 if row[4] in westdata.keys():
#                     southeastdata[row[4]] += abs(float(row[6]) * southeast_coef - float(row[8]) + southeast_incept) / math.sqrt(float(southeast_coef) ** 2 + 1)
        if len(northeast) != 0:
            northeast_coef, northeast_incept = regs(northeast)
#             for row in whole:
#                 if row[4] in westdata.keys():
#                     northeastdata[row[4]] += abs(float(row[6]) * northeast_coef - float(row[8]) + northeast_incept) / math.sqrt(float(northeast_coef) ** 2 + 1)
        if len(southwest) != 0:
            southwest_coef, southwest_incept = regs(southwest)
#             for row in whole:
#                 if row[4] in westdata.keys():
#                     southwestdata[row[4]] += abs(float(row[6]) * southwest_coef - float(row[8]) + southwest_incept) / math.sqrt(float(southwest_coef) ** 2 + 1)
#         west_coef, west_incept = regs(west)
#         midwest_coef, midwest_incept = regs(midwest)
#         southwest_coef, southwest_incept = regs(southwest)
#         southeast_coef, southeast_incept = regs(southeast)
#         northeast_coef, northeast_incept = regs(northeast)
        for row in whole:
            if row[4] in westdata.keys():
                westdata[row[4]] += abs(float(row[6]) * west_coef - float(row[8]) + west_incept) / math.sqrt(float(west_coef) ** 2 + 1)
                midwestdata[row[4]] += abs(float(row[6]) * midwest_coef - float(row[8]) + midwest_incept) / math.sqrt(float(midwest_coef) ** 2 + 1)
                southeastdata[row[4]] += abs(float(row[6]) * southeast_coef - float(row[8]) + southeast_incept) / math.sqrt(float(southeast_coef) ** 2 + 1)
                northeastdata[row[4]] += abs(float(row[6]) * northeast_coef - float(row[8]) + northeast_incept) / math.sqrt(float(northeast_coef) ** 2 + 1)
                southwestdata[row[4]] += abs(float(row[6]) * southwest_coef - float(row[8]) + northeast_incept) / math.sqrt(float(southwest_coef) ** 2 + 1)
        new_west = []
        new_midwest = []
        new_southwest = []
        new_northwest = []
        new_southeast = []
        for key in westdata.keys():
            tmp = [westdata[key], midwestdata[key], southeastdata[key], northeastdata[key], southwestdata[key]]
            idx = tmp.index(min(tmp))
            if idx == 0:
                new_west.append(key)
            elif idx == 1:
                new_midwest.append(key)
            elif idx == 2:
                new_southeast.append(key)
            elif idx == 3:
                new_northwest.append(key)
            else:
                new_southwest.append(key)
        new_west.sort()
        new_midwest.sort()
        new_southwest.sort()
        new_northwest.sort()
        new_southeast.sort()
        if (west == new_west and midwest == new_midwest and southeast == new_southeast and southwest == new_southwest and northeast == new_northwest):
            flag = 0
        else:
            west = new_west
            midwest = new_midwest
            southeast = new_southeast
            southwest = new_southwest
            northeast = new_northwest
        print southwest
    print "west includes:", west
    print "midwest includes:", midwest
    print "southeast includes:", southeast
    print "northeast includes:", northeast
    print "southwest includes:", southwest

# %%
def regs(datagroup):
    charge = []
    poverty = []
    for i in range(1, len(whole)):
        if whole[i][7] != 'what' and whole[i][4] in datagroup:
            charge.append([float(whole[i][6])])
            poverty.append(float(whole[i][8]))
    regr = linear_model.LinearRegression()
    regr.fit(charge, poverty)
    return regr.coef_[0], regr.predict(0)[0]

# %%
print regs(west)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-da970709ca92> in <module>()
# ----> 1 print regs(west)
#
# NameError: name 'west' is not defined

# %%
#kmeans()

# %%
a = ["a", "1", "6"]
b = ["a", "1", "6"]
print a == b
# Out:
# True

# %%
west = ['AK', 'CA', 'CO', 'HI', 'ID', 'MT', 'NV', 'OR', 'UT', 'WA', 'WY']
midwest = ['ND', 'SD', 'NE', 'KS', 'MN', 'IA', 'MO', 'WI', 'IL', 'IN', 'MI', 'OH']
southwest = ['NM', 'AZ', 'OK', 'TX']
southeast = ['AR', 'LA', 'MS', 'AL', 'TN', 'KY', 'GA', 'FL', 'WV', 'VA', "SC", "NC"]
northeast = ['CT', 'DE', 'ME', 'MD', 'MA', 'NH', 'NH', 'NY', 'PA', 'RI', 'VT', "DC", "NJ"]
west.sort()
midwest.sort()
southwest.sort()
southeast.sort()
northeast.sort()
west_coef, west_incept = 0, 0
midwest_coef, midwest_incept = 0, 0
southeast_coef, southeast_incept = 0, 0
northeast_coef, northeast_incept = 0, 0
southwest_coef, southwest_incept = 0, 0
westdata = dict()
midwestdata = dict()
southeastdata = dict()
northeastdata = dict()
southwestdata = dict()
allstates = west + midwest + southwest + southeast + northeast
for state in allstates:
    westdata[state] = 0
    midwestdata[state] = 0
    southeastdata[state] = 0
    northeastdata[state] = 0
    southwestdata[state] = 0
west_coef, west_incept = regs(west)
midwest_coef, midwest_incept = regs(midwest)
southwest_coef, southwest_incept = regs(southwest)
southeast_coef, southeast_incept = regs(southeast)
northeast_coef, northeast_incept = regs(northeast)
for row in whole:
    if row[4] in westdata.keys():
        westdata[row[4]] += abs(float(row[6]) * west_coef - float(row[8]) + west_incept) / math.sqrt(float(west_coef) ** 2 + 1)
        midwestdata[row[4]] += abs(float(row[6]) * midwest_coef - float(row[8]) + midwest_incept) / math.sqrt(float(midwest_coef) ** 2 + 1)
        southeastdata[row[4]] += abs(float(row[6]) * southeast_coef - float(row[8]) + southeast_incept) / math.sqrt(float(southeast_coef) ** 2 + 1)
        northeastdata[row[4]] += abs(float(row[6]) * northeast_coef - float(row[8]) + northeast_incept) / math.sqrt(float(northeast_coef) ** 2 + 1)
        southwestdata[row[4]] += abs(float(row[6]) * southwest_coef - float(row[8]) + northeast_incept) / math.sqrt(float(southwest_coef) ** 2 + 1)
new_west = []
new_midwest = []
new_southwest = []
new_northeast = []
new_southeast = []
for key in westdata.keys():
    tmp = [westdata[key], midwestdata[key], southeastdata[key], northeastdata[key], southwestdata[key]]
    idx = tmp.index(min(tmp))
    if idx == 0:
        new_west.append(key)
    elif idx == 1:
        new_midwest.append(key)
    elif idx == 2:
        new_southeast.append(key)
    elif idx == 3:
        new_northwest.append(key)
    else:
        new_southwest.append(key)
new_west.sort()
new_midwest.sort()
new_southwest.sort()
new_northeast.sort()
new_southeast.sort()
# if (west == new_west and midwest == new_midwest and southeast == new_southeast and southwest == new_southwest and northeast == new_northwest):
#     flag = 0
# else:
#     west = new_west
#     midwest = new_midwest
#     southeast = new_southeast
#     southwest = new_southwest
#     northeast = new_northwest
print "west includes:", new_west
print "midwest includes:", new_midwest
print "southeast includes:", new_southeast
print "northeast includes:", new_northeast
print "southwest includes:", new_southwest
# Out:
# west includes: []
# midwest includes: ['AK', 'CO', 'DC', 'DE', 'HI', 'IL', 'IN', 'KS', 'MD', 'ME', 'MI', 'MN', 'MO', 'MT', 'ND', 'NJ', 'NY', 'OH', 'PA', 'SD', 'UT', 'VA', 'WA', 'WY']
# southeast includes: ['AL', 'AR', 'AZ', 'CA', 'FL', 'GA', 'ID', 'KY', 'LA', 'MS', 'NC', 'NM', 'NV', 'OK', 'OR', 'SC', 'TN', 'TX', 'WV']
# northeast includes: []
# southwest includes: ['CT', 'IA', 'MA', 'NE', 'NH', 'RI', 'VT', 'WI']

# %%
#west = ['AK', 'CA', 'CO', 'HI', 'ID', 'MT', 'NV', 'OR', 'UT', 'WA', 'WY']
midwest = ['AK', 'DC', 'CO', 'DE', 'HI', 'IL', 'IN', 'KS', 'MD', 'ME', 'MI', 'MN', 'MO', 'MT', 'ND', 'NJ','NY', 'OH', 'PA', 'SD', 'UT', 'VA', 'WA', 'WY']
southwest = ['CT', 'IA', 'MA', 'NE', 'NH', 'RI', 'VT', 'WI']
southeast = ['AL', 'AR', 'AZ', 'CA', 'FL', 'GA', 'ID', 'KY', 'LA', 'MS', 'NC', 'NM', 'NV', 'OK', 'OR', 'SC', 'TN', 'TX', 'WV']
#northeast = ['CT', 'DE', 'ME', 'MD', 'MA', 'NH', 'NH', 'NY', 'PA', 'RI', 'VT']
#west.sort()
midwest.sort()
southwest.sort()
southeast.sort()
#northeast.sort()
#west_coef, west_incept = 0, 0
midwest_coef, midwest_incept = 0, 0
southeast_coef, southeast_incept = 0, 0
#northeast_coef, northeast_incept = 0, 0
southwest_coef, southwest_incept = 0, 0
#westdata = dict()
midwestdata = dict()
southeastdata = dict()
#northeastdata = dict()
southwestdata = dict()
allstates = midwest + southwest + southeast
for state in allstates:
    #westdata[state] = 0
    midwestdata[state] = 0
    southeastdata[state] = 0
    #northeastdata[state] = 0
    southwestdata[state] = 0
#west_coef, west_incept = regs(west)
midwest_coef, midwest_incept = regs(midwest)
southwest_coef, southwest_incept = regs(southwest)
southeast_coef, southeast_incept = regs(southeast)
#northeast_coef, northeast_incept = regs(northeast)
for row in whole:
    if row[4] in westdata.keys():
#        westdata[row[4]] += abs(float(row[6]) * west_coef - float(row[8]) + west_incept) / math.sqrt(float(west_coef) ** 2 + 1)
        midwestdata[row[4]] += abs(float(row[6]) * midwest_coef - float(row[8]) + midwest_incept) / math.sqrt(float(midwest_coef) ** 2 + 1)
        southeastdata[row[4]] += abs(float(row[6]) * southeast_coef - float(row[8]) + southeast_incept) / math.sqrt(float(southeast_coef) ** 2 + 1)
#        northeastdata[row[4]] += abs(float(row[6]) * northeast_coef - float(row[8]) + northeast_incept) / math.sqrt(float(northeast_coef) ** 2 + 1)
        southwestdata[row[4]] += abs(float(row[6]) * southwest_coef - float(row[8]) + northeast_incept) / math.sqrt(float(southwest_coef) ** 2 + 1)
#new_west = []
new_midwest = []
new_southwest = []
#new_northeast = []
new_southeast = []
for key in westdata.keys():
    tmp = [midwestdata[key], southeastdata[key], southwestdata[key]]
    idx = tmp.index(min(tmp))
    if idx == 0:
        new_midwest.append(key)
    elif idx == 1:
        new_southeast.append(key)
    elif idx == 2:
        new_southwest.append(key)
#     elif idx == 3:
#         new_northwest.append(key)
#     else:
#         new_southwest.append(key)
#new_west.sort()
new_midwest.sort()
new_southwest.sort()
#new_northwest.sort()
new_southeast.sort()
# if (west == new_west and midwest == new_midwest and southeast == new_southeast and southwest == new_southwest and northeast == new_northwest):
#     flag = 0
# else:
#     west = new_west
#     midwest = new_midwest
#     southeast = new_southeast
#     southwest = new_southwest
#     northeast = new_northwest
#print "west includes:", new_west
print "midwest includes:", new_midwest
print "southeast includes:", new_southeast
#print "northeast includes:", new_northeast
print "southwest includes:", new_southwest
# Out:
# midwest includes: ['AK', 'CO', 'CT', 'DC', 'DE', 'HI', 'IL', 'IN', 'KS', 'MD', 'ME', 'MI', 'MN', 'MT', 'ND', 'NE', 'NH', 'NJ', 'NY', 'OH', 'PA', 'RI', 'SD', 'UT', 'VA', 'WA', 'WI', 'WY']
# southeast includes: ['AL', 'AR', 'AZ', 'CA', 'FL', 'GA', 'ID', 'KY', 'LA', 'MO', 'MS', 'NC', 'NM', 'NV', 'OK', 'OR', 'SC', 'TN', 'TX', 'WV']
# southwest includes: ['IA', 'MA', 'VT']

# %%
midwest = new_midwest
southwest = new_southwest
southeast = new_southeast

# %%
#west = ['AK', 'CA', 'CO', 'HI', 'ID', 'MT', 'NV', 'OR', 'UT', 'WA', 'WY']
#midwest = ['AK', 'CO', 'CT', 'DE', 'HI', 'IA', 'IL', 'IN', 'KS', 'MD', 'ME', 'MI', 'MN', 'MT', 'ND', 'NE', 'NH', 'NY', 'OH', 'PA', 'RI', 'SD', 'UT', 'VA', 'WA', 'WI', 'WY']
#southwest = ['MA', 'VT']
#southeast = ['AL', 'AR', 'AZ', 'CA', 'FL', 'GA', 'ID', 'KY', 'LA', 'MO', 'MS', 'NC', 'NM', 'NV', 'OK', 'OR', 'SC', 'TN', 'TX', 'WV']
#northeast = ['CT', 'DE', 'ME', 'MD', 'MA', 'NH', 'NH', 'NY', 'PA', 'RI', 'VT']
#west.sort()
midwest.sort()
southwest.sort()
southeast.sort()
#northeast.sort()
#west_coef, west_incept = 0, 0
midwest_coef, midwest_incept = 0, 0
southeast_coef, southeast_incept = 0, 0
#northeast_coef, northeast_incept = 0, 0
southwest_coef, southwest_incept = 0, 0
#westdata = dict()
midwestdata = dict()
southeastdata = dict()
#northeastdata = dict()
southwestdata = dict()
allstates = midwest + southwest + southeast
for state in allstates:
    #westdata[state] = 0
    midwestdata[state] = 0
    southeastdata[state] = 0
    #northeastdata[state] = 0
    southwestdata[state] = 0
#west_coef, west_incept = regs(west)
midwest_coef, midwest_incept = regs(midwest)
southwest_coef, southwest_incept = regs(southwest)
southeast_coef, southeast_incept = regs(southeast)
#northeast_coef, northeast_incept = regs(northeast)
for row in whole:
    if row[4] in westdata.keys():
#        westdata[row[4]] += abs(float(row[6]) * west_coef - float(row[8]) + west_incept) / math.sqrt(float(west_coef) ** 2 + 1)
        midwestdata[row[4]] += abs(float(row[6]) * midwest_coef - float(row[8]) + midwest_incept) / math.sqrt(float(midwest_coef) ** 2 + 1)
        southeastdata[row[4]] += abs(float(row[6]) * southeast_coef - float(row[8]) + southeast_incept) / math.sqrt(float(southeast_coef) ** 2 + 1)
#        northeastdata[row[4]] += abs(float(row[6]) * northeast_coef - float(row[8]) + northeast_incept) / math.sqrt(float(northeast_coef) ** 2 + 1)
        southwestdata[row[4]] += abs(float(row[6]) * southwest_coef - float(row[8]) + northeast_incept) / math.sqrt(float(southwest_coef) ** 2 + 1)
#new_west = []
new_midwest = []
new_southwest = []
#new_northeast = []
new_southeast = []
for key in westdata.keys():
    tmp = [midwestdata[key], southeastdata[key], southwestdata[key]]
    idx = tmp.index(min(tmp))
    if idx == 0:
        new_midwest.append(key)
    elif idx == 1:
        new_southeast.append(key)
    elif idx == 2:
        new_southwest.append(key)
#     elif idx == 3:
#         new_northwest.append(key)
#     else:
#         new_southwest.append(key)
#new_west.sort()
new_midwest.sort()
new_southwest.sort()
#new_northwest.sort()
new_southeast.sort()
# if (west == new_west and midwest == new_midwest and southeast == new_southeast and southwest == new_southwest and northeast == new_northwest):
#     flag = 0
# else:
#     west = new_west
#     midwest = new_midwest
#     southeast = new_southeast
#     southwest = new_southwest
#     northeast = new_northwest
#print "west includes:", new_west
print "midwest includes:", new_midwest
print "southeast includes:", new_southeast
#print "northeast includes:", new_northeast
print "southwest includes:", new_southwest
# Out:
# midwest includes: ['AK', 'CO', 'CT', 'DC', 'DE', 'HI', 'IA', 'IL', 'IN', 'KS', 'MA', 'MD', 'ME', 'MN', 'MT', 'ND', 'NE', 'NH', 'NJ', 'NY', 'OH', 'PA', 'RI', 'SD', 'UT', 'VA', 'WA', 'WI', 'WY']
# southeast includes: ['AL', 'AR', 'AZ', 'CA', 'FL', 'GA', 'ID', 'KY', 'LA', 'MI', 'MO', 'MS', 'NC', 'NM', 'NV', 'OK', 'OR', 'SC', 'TN', 'TX', 'WV']
# southwest includes: ['VT']

# %%
midwest = new_midwest
southwest = new_southwest
southeast = new_southeast

# %%
#west = ['AK', 'CA', 'CO', 'HI', 'ID', 'MT', 'NV', 'OR', 'UT', 'WA', 'WY']
#midwest = ['AK', 'CO', 'CT', 'DE', 'HI', 'IA', 'IL', 'IN', 'KS', 'MA', 'MD', 'ME', 'MI', 'MN', 'MT', 'ND', 'NE', 'NH', 'NY', 'OH', 'PA', 'RI', 'SD', 'UT', 'VA', 'VT', 'WA', 'WI', 'WY']
#southwest = ['MA', 'VT']
#southeast = ['AL', 'AR', 'AZ', 'CA', 'FL', 'GA', 'ID', 'KY', 'LA', 'MO', 'MS', 'NC', 'NM', 'NV', 'OK', 'OR', 'SC', 'TN', 'TX', 'WV']
#northeast = ['CT', 'DE', 'ME', 'MD', 'MA', 'NH', 'NH', 'NY', 'PA', 'RI', 'VT']
#west.sort()
midwest.sort()
southwest.sort()
southeast.sort()
#northeast.sort()
#west_coef, west_incept = 0, 0
midwest_coef, midwest_incept = 0, 0
southeast_coef, southeast_incept = 0, 0
#northeast_coef, northeast_incept = 0, 0
southwest_coef, southwest_incept = 0, 0
#westdata = dict()
midwestdata = dict()
southeastdata = dict()
#northeastdata = dict()
southwestdata = dict()
allstates = midwest + southeast + southwest
for state in allstates:
    #westdata[state] = 0
    midwestdata[state] = 0
    southeastdata[state] = 0
    #northeastdata[state] = 0
    southwestdata[state] = 0
#west_coef, west_incept = regs(west)
midwest_coef, midwest_incept = regs(midwest)
southwest_coef, southwest_incept = regs(southwest)
southeast_coef, southeast_incept = regs(southeast)
#northeast_coef, northeast_incept = regs(northeast)
for row in whole:
    if row[4] in westdata.keys():
#        westdata[row[4]] += abs(float(row[6]) * west_coef - float(row[8]) + west_incept) / math.sqrt(float(west_coef) ** 2 + 1)
        midwestdata[row[4]] += abs(float(row[6]) * midwest_coef - float(row[8]) + midwest_incept) / math.sqrt(float(midwest_coef) ** 2 + 1)
        southeastdata[row[4]] += abs(float(row[6]) * southeast_coef - float(row[8]) + southeast_incept) / math.sqrt(float(southeast_coef) ** 2 + 1)
#        northeastdata[row[4]] += abs(float(row[6]) * northeast_coef - float(row[8]) + northeast_incept) / math.sqrt(float(northeast_coef) ** 2 + 1)
        southwestdata[row[4]] += abs(float(row[6]) * southwest_coef - float(row[8]) + northeast_incept) / math.sqrt(float(southwest_coef) ** 2 + 1)
#new_west = []
new_midwest = []
new_southwest = []
#new_northeast = []
new_southeast = []
for key in westdata.keys():
    tmp = [midwestdata[key], southeastdata[key], southwestdata[key]]
    idx = tmp.index(min(tmp))
    if idx == 0:
        new_midwest.append(key)
    elif idx == 1:
        new_southeast.append(key)
    elif idx == 2:
        new_southwest.append(key)
#     elif idx == 3:
#         new_northwest.append(key)
#     else:
#         new_southwest.append(key)
#new_west.sort()
new_midwest.sort()
new_southwest.sort()
#new_northwest.sort()
new_southeast.sort()
# if (west == new_west and midwest == new_midwest and southeast == new_southeast and southwest == new_southwest and northeast == new_northwest):
#     flag = 0
# else:
#     west = new_west
#     midwest = new_midwest
#     southeast = new_southeast
#     southwest = new_southwest
#     northeast = new_northwest
#print "west includes:", new_west
print "midwest includes:", new_midwest
print "southeast includes:", new_southeast
#print "northeast includes:", new_northeast
print "southwest includes:", new_southwest
# Out:
# midwest includes: ['IL', 'IN', 'KS', 'NJ', 'NY', 'OH']
# southeast includes: ['AL', 'AR', 'AZ', 'CA', 'FL', 'GA', 'ID', 'KY', 'LA', 'MI', 'MO', 'MS', 'NC', 'NM', 'NV', 'OK', 'OR', 'SC', 'TN', 'TX', 'WV']
# southwest includes: ['AK', 'CO', 'CT', 'DC', 'DE', 'HI', 'IA', 'MA', 'MD', 'ME', 'MN', 'MT', 'ND', 'NE', 'NH', 'PA', 'RI', 'SD', 'UT', 'VA', 'VT', 'WA', 'WI', 'WY']

# %%
midwest = new_midwest
southwest = new_southwest
southeast = new_southeast

# %%
#west = ['AK', 'CA', 'CO', 'HI', 'ID', 'MT', 'NV', 'OR', 'UT', 'WA', 'WY']
#midwest = ['AK', 'CO', 'CT', 'DE', 'HI', 'IA', 'IL', 'IN', 'KS', 'MA', 'MD', 'ME', 'MI', 'MN', 'MT', 'ND', 'NE', 'NH', 'NY', 'OH', 'PA', 'RI', 'SD', 'UT', 'VA', 'VT', 'WA', 'WI', 'WY']
#southwest = ['MA', 'VT']
#southeast = ['AL', 'AR', 'AZ', 'CA', 'FL', 'GA', 'ID', 'KY', 'LA', 'MO', 'MS', 'NC', 'NM', 'NV', 'OK', 'OR', 'SC', 'TN', 'TX', 'WV']
#northeast = ['CT', 'DE', 'ME', 'MD', 'MA', 'NH', 'NH', 'NY', 'PA', 'RI', 'VT']
#west.sort()
midwest.sort()
southwest.sort()
southeast.sort()
#northeast.sort()
#west_coef, west_incept = 0, 0
midwest_coef, midwest_incept = 0, 0
southeast_coef, southeast_incept = 0, 0
#northeast_coef, northeast_incept = 0, 0
southwest_coef, southwest_incept = 0, 0
#westdata = dict()
midwestdata = dict()
southeastdata = dict()
#northeastdata = dict()
southwestdata = dict()
allstates = midwest + southeast + southwest
for state in allstates:
    #westdata[state] = 0
    midwestdata[state] = 0
    southeastdata[state] = 0
    #northeastdata[state] = 0
    southwestdata[state] = 0
#west_coef, west_incept = regs(west)
midwest_coef, midwest_incept = regs(midwest)
southwest_coef, southwest_incept = regs(southwest)
southeast_coef, southeast_incept = regs(southeast)
#northeast_coef, northeast_incept = regs(northeast)
for row in whole:
    if row[4] in westdata.keys():
#        westdata[row[4]] += abs(float(row[6]) * west_coef - float(row[8]) + west_incept) / math.sqrt(float(west_coef) ** 2 + 1)
        midwestdata[row[4]] += abs(float(row[6]) * midwest_coef - float(row[8]) + midwest_incept) / math.sqrt(float(midwest_coef) ** 2 + 1)
        southeastdata[row[4]] += abs(float(row[6]) * southeast_coef - float(row[8]) + southeast_incept) / math.sqrt(float(southeast_coef) ** 2 + 1)
#        northeastdata[row[4]] += abs(float(row[6]) * northeast_coef - float(row[8]) + northeast_incept) / math.sqrt(float(northeast_coef) ** 2 + 1)
        southwestdata[row[4]] += abs(float(row[6]) * southwest_coef - float(row[8]) + northeast_incept) / math.sqrt(float(southwest_coef) ** 2 + 1)
#new_west = []
new_midwest = []
new_southwest = []
#new_northeast = []
new_southeast = []
for key in westdata.keys():
    tmp = [midwestdata[key], southeastdata[key], southwestdata[key]]
    idx = tmp.index(min(tmp))
    if idx == 0:
        new_midwest.append(key)
    elif idx == 1:
        new_southeast.append(key)
    elif idx == 2:
        new_southwest.append(key)
#     elif idx == 3:
#         new_northwest.append(key)
#     else:
#         new_southwest.append(key)
#new_west.sort()
new_midwest.sort()
new_southwest.sort()
#new_northwest.sort()
new_southeast.sort()
# if (west == new_west and midwest == new_midwest and southeast == new_southeast and southwest == new_southwest and northeast == new_northwest):
#     flag = 0
# else:
#     west = new_west
#     midwest = new_midwest
#     southeast = new_southeast
#     southwest = new_southwest
#     northeast = new_northwest
#print "west includes:", new_west
print "midwest includes:", new_midwest
print "southeast includes:", new_southeast
#print "northeast includes:", new_northeast
print "southwest includes:", new_southwest
# Out:
# midwest includes: ['AK', 'CO', 'HI', 'IL', 'IN', 'KS', 'ME', 'MI', 'MT', 'NJ', 'NY', 'OH', 'PA', 'SD', 'VA', 'WA', 'WY']
# southeast includes: ['AL', 'AR', 'AZ', 'CA', 'FL', 'GA', 'ID', 'KY', 'LA', 'MO', 'MS', 'NC', 'NM', 'NV', 'OK', 'OR', 'SC', 'TN', 'TX', 'WV']
# southwest includes: ['CT', 'DC', 'DE', 'IA', 'MA', 'MD', 'MN', 'ND', 'NE', 'NH', 'RI', 'UT', 'VT', 'WI']

# %%
print midwest == new_midwest
print southeast == new_southeast
print southwest == new_southwest
print len(midwest) + len(southwest) + len(southeast)
# Out:
# False
# False
# False
# 51

# %%
midwest = new_midwest
southwest = new_southwest
southeast = new_southeast

# %%
#west = ['AK', 'CA', 'CO', 'HI', 'ID', 'MT', 'NV', 'OR', 'UT', 'WA', 'WY']
#midwest = ['AK', 'CO', 'CT', 'DE', 'HI', 'IA', 'IL', 'IN', 'KS', 'MA', 'MD', 'ME', 'MI', 'MN', 'MT', 'ND', 'NE', 'NH', 'NY', 'OH', 'PA', 'RI', 'SD', 'UT', 'VA', 'VT', 'WA', 'WI', 'WY']
#southwest = ['MA', 'VT']
#southeast = ['AL', 'AR', 'AZ', 'CA', 'FL', 'GA', 'ID', 'KY', 'LA', 'MO', 'MS', 'NC', 'NM', 'NV', 'OK', 'OR', 'SC', 'TN', 'TX', 'WV']
#northeast = ['CT', 'DE', 'ME', 'MD', 'MA', 'NH', 'NH', 'NY', 'PA', 'RI', 'VT']
#west.sort()
midwest.sort()
southwest.sort()
southeast.sort()
#northeast.sort()
#west_coef, west_incept = 0, 0
midwest_coef, midwest_incept = 0, 0
southeast_coef, southeast_incept = 0, 0
#northeast_coef, northeast_incept = 0, 0
southwest_coef, southwest_incept = 0, 0
#westdata = dict()
midwestdata = dict()
southeastdata = dict()
#northeastdata = dict()
southwestdata = dict()
allstates = midwest + southeast + southwest
for state in allstates:
    #westdata[state] = 0
    midwestdata[state] = 0
    southeastdata[state] = 0
    #northeastdata[state] = 0
    southwestdata[state] = 0
#west_coef, west_incept = regs(west)
midwest_coef, midwest_incept = regs(midwest)
southwest_coef, southwest_incept = regs(southwest)
southeast_coef, southeast_incept = regs(southeast)
#northeast_coef, northeast_incept = regs(northeast)
for row in whole:
    if row[4] in westdata.keys():
#        westdata[row[4]] += abs(float(row[6]) * west_coef - float(row[8]) + west_incept) / math.sqrt(float(west_coef) ** 2 + 1)
        midwestdata[row[4]] += abs(float(row[6]) * midwest_coef - float(row[8]) + midwest_incept) / math.sqrt(float(midwest_coef) ** 2 + 1)
        southeastdata[row[4]] += abs(float(row[6]) * southeast_coef - float(row[8]) + southeast_incept) / math.sqrt(float(southeast_coef) ** 2 + 1)
#        northeastdata[row[4]] += abs(float(row[6]) * northeast_coef - float(row[8]) + northeast_incept) / math.sqrt(float(northeast_coef) ** 2 + 1)
        southwestdata[row[4]] += abs(float(row[6]) * southwest_coef - float(row[8]) + northeast_incept) / math.sqrt(float(southwest_coef) ** 2 + 1)
#new_west = []
new_midwest = []
new_southwest = []
#new_northeast = []
new_southeast = []
for key in westdata.keys():
    tmp = [midwestdata[key], southeastdata[key], southwestdata[key]]
    idx = tmp.index(min(tmp))
    if idx == 0:
        new_midwest.append(key)
    elif idx == 1:
        new_southeast.append(key)
    elif idx == 2:
        new_southwest.append(key)
#     elif idx == 3:
#         new_northwest.append(key)
#     else:
#         new_southwest.append(key)
#new_west.sort()
new_midwest.sort()
new_southwest.sort()
#new_northwest.sort()
new_southeast.sort()
# if (west == new_west and midwest == new_midwest and southeast == new_southeast and southwest == new_southwest and northeast == new_northwest):
#     flag = 0
# else:
#     west = new_west
#     midwest = new_midwest
#     southeast = new_southeast
#     southwest = new_southwest
#     northeast = new_northwest
#print "west includes:", new_west
print "midwest includes:", new_midwest
print "southeast includes:", new_southeast
#print "northeast includes:", new_northeast
print "southwest includes:", new_southwest
# Out:
# midwest includes: ['AK', 'CO', 'DC', 'DE', 'HI', 'IL', 'IN', 'KS', 'MD', 'ME', 'MI', 'MN', 'MO', 'MT', 'ND', 'NJ', 'NY', 'OH', 'PA', 'SD', 'UT', 'VA', 'WA', 'WY']
# southeast includes: ['AL', 'AR', 'AZ', 'CA', 'FL', 'GA', 'ID', 'KY', 'LA', 'MS', 'NC', 'NM', 'NV', 'OK', 'OR', 'SC', 'TN', 'TX', 'WV']
# southwest includes: ['CT', 'IA', 'MA', 'NE', 'NH', 'RI', 'VT', 'WI']

# %%
print midwest == new_midwest
print southeast == new_southeast
print southwest == new_southwest
print len(midwest) + len(southwest) + len(southeast)
# Out:
# False
# False
# False
# 51

# %%
midwest = new_midwest
southwest = new_southwest
southeast = new_southeast
#west = ['AK', 'CA', 'CO', 'HI', 'ID', 'MT', 'NV', 'OR', 'UT', 'WA', 'WY']
#midwest = ['AK', 'CO', 'CT', 'DE', 'HI', 'IA', 'IL', 'IN', 'KS', 'MA', 'MD', 'ME', 'MI', 'MN', 'MT', 'ND', 'NE', 'NH', 'NY', 'OH', 'PA', 'RI', 'SD', 'UT', 'VA', 'VT', 'WA', 'WI', 'WY']
#southwest = ['MA', 'VT']
#southeast = ['AL', 'AR', 'AZ', 'CA', 'FL', 'GA', 'ID', 'KY', 'LA', 'MO', 'MS', 'NC', 'NM', 'NV', 'OK', 'OR', 'SC', 'TN', 'TX', 'WV']
#northeast = ['CT', 'DE', 'ME', 'MD', 'MA', 'NH', 'NH', 'NY', 'PA', 'RI', 'VT']
#west.sort()
midwest.sort()
southwest.sort()
southeast.sort()
#northeast.sort()
#west_coef, west_incept = 0, 0
midwest_coef, midwest_incept = 0, 0
southeast_coef, southeast_incept = 0, 0
#northeast_coef, northeast_incept = 0, 0
southwest_coef, southwest_incept = 0, 0
#westdata = dict()
midwestdata = dict()
southeastdata = dict()
#northeastdata = dict()
southwestdata = dict()
allstates = midwest + southeast + southwest
for state in allstates:
    #westdata[state] = 0
    midwestdata[state] = 0
    southeastdata[state] = 0
    #northeastdata[state] = 0
    southwestdata[state] = 0
#west_coef, west_incept = regs(west)
midwest_coef, midwest_incept = regs(midwest)
southwest_coef, southwest_incept = regs(southwest)
southeast_coef, southeast_incept = regs(southeast)
#northeast_coef, northeast_incept = regs(northeast)
for row in whole:
    if row[4] in westdata.keys():
#        westdata[row[4]] += abs(float(row[6]) * west_coef - float(row[8]) + west_incept) / math.sqrt(float(west_coef) ** 2 + 1)
        midwestdata[row[4]] += abs(float(row[6]) * midwest_coef - float(row[8]) + midwest_incept) / math.sqrt(float(midwest_coef) ** 2 + 1)
        southeastdata[row[4]] += abs(float(row[6]) * southeast_coef - float(row[8]) + southeast_incept) / math.sqrt(float(southeast_coef) ** 2 + 1)
#        northeastdata[row[4]] += abs(float(row[6]) * northeast_coef - float(row[8]) + northeast_incept) / math.sqrt(float(northeast_coef) ** 2 + 1)
        southwestdata[row[4]] += abs(float(row[6]) * southwest_coef - float(row[8]) + northeast_incept) / math.sqrt(float(southwest_coef) ** 2 + 1)
#new_west = []
new_midwest = []
new_southwest = []
#new_northeast = []
new_southeast = []
for key in westdata.keys():
    tmp = [midwestdata[key], southeastdata[key], southwestdata[key]]
    idx = tmp.index(min(tmp))
    if idx == 0:
        new_midwest.append(key)
    elif idx == 1:
        new_southeast.append(key)
    elif idx == 2:
        new_southwest.append(key)
#     elif idx == 3:
#         new_northwest.append(key)
#     else:
#         new_southwest.append(key)
#new_west.sort()
new_midwest.sort()
new_southwest.sort()
#new_northwest.sort()
new_southeast.sort()
# if (west == new_west and midwest == new_midwest and southeast == new_southeast and southwest == new_southwest and northeast == new_northwest):
#     flag = 0
# else:
#     west = new_west
#     midwest = new_midwest
#     southeast = new_southeast
#     southwest = new_southwest
#     northeast = new_northwest
#print "west includes:", new_west
print "midwest includes:", new_midwest
print "southeast includes:", new_southeast
#print "northeast includes:", new_northeast
print "southwest includes:", new_southwest
print midwest == new_midwest
print southeast == new_southeast
print southwest == new_southwest
print len(midwest) + len(southwest) + len(southeast)
# Out:
# midwest includes: ['AK', 'CO', 'CT', 'DC', 'DE', 'HI', 'IL', 'IN', 'KS', 'MD', 'ME', 'MI', 'MN', 'MT', 'ND', 'NE', 'NH', 'NJ', 'NY', 'OH', 'PA', 'RI', 'SD', 'UT', 'VA', 'WA', 'WI', 'WY']
# southeast includes: ['AL', 'AR', 'AZ', 'CA', 'FL', 'GA', 'ID', 'KY', 'LA', 'MO', 'MS', 'NC', 'NM', 'NV', 'OK', 'OR', 'SC', 'TN', 'TX', 'WV']
# southwest includes: ['IA', 'MA', 'VT']
# False
# False
# False
# 51

# %%
midwest = new_midwest
southwest = new_southwest
southeast = new_southeast
#west = ['AK', 'CA', 'CO', 'HI', 'ID', 'MT', 'NV', 'OR', 'UT', 'WA', 'WY']
#midwest = ['AK', 'CO', 'CT', 'DE', 'HI', 'IA', 'IL', 'IN', 'KS', 'MA', 'MD', 'ME', 'MI', 'MN', 'MT', 'ND', 'NE', 'NH', 'NY', 'OH', 'PA', 'RI', 'SD', 'UT', 'VA', 'VT', 'WA', 'WI', 'WY']
#southwest = ['MA', 'VT']
#southeast = ['AL', 'AR', 'AZ', 'CA', 'FL', 'GA', 'ID', 'KY', 'LA', 'MO', 'MS', 'NC', 'NM', 'NV', 'OK', 'OR', 'SC', 'TN', 'TX', 'WV']
#northeast = ['CT', 'DE', 'ME', 'MD', 'MA', 'NH', 'NH', 'NY', 'PA', 'RI', 'VT']
#west.sort()
midwest.sort()
southwest.sort()
southeast.sort()
#northeast.sort()
#west_coef, west_incept = 0, 0
midwest_coef, midwest_incept = 0, 0
southeast_coef, southeast_incept = 0, 0
#northeast_coef, northeast_incept = 0, 0
southwest_coef, southwest_incept = 0, 0
#westdata = dict()
midwestdata = dict()
southeastdata = dict()
#northeastdata = dict()
southwestdata = dict()
allstates = midwest + southeast + southwest
for state in allstates:
    #westdata[state] = 0
    midwestdata[state] = 0
    southeastdata[state] = 0
    #northeastdata[state] = 0
    southwestdata[state] = 0
#west_coef, west_incept = regs(west)
midwest_coef, midwest_incept = regs(midwest)
southwest_coef, southwest_incept = regs(southwest)
southeast_coef, southeast_incept = regs(southeast)
#northeast_coef, northeast_incept = regs(northeast)
for row in whole:
    if row[4] in westdata.keys():
#        westdata[row[4]] += abs(float(row[6]) * west_coef - float(row[8]) + west_incept) / math.sqrt(float(west_coef) ** 2 + 1)
        midwestdata[row[4]] += abs(float(row[6]) * midwest_coef - float(row[8]) + midwest_incept) / math.sqrt(float(midwest_coef) ** 2 + 1)
        southeastdata[row[4]] += abs(float(row[6]) * southeast_coef - float(row[8]) + southeast_incept) / math.sqrt(float(southeast_coef) ** 2 + 1)
#        northeastdata[row[4]] += abs(float(row[6]) * northeast_coef - float(row[8]) + northeast_incept) / math.sqrt(float(northeast_coef) ** 2 + 1)
        southwestdata[row[4]] += abs(float(row[6]) * southwest_coef - float(row[8]) + northeast_incept) / math.sqrt(float(southwest_coef) ** 2 + 1)
#new_west = []
new_midwest = []
new_southwest = []
#new_northeast = []
new_southeast = []
for key in westdata.keys():
    tmp = [midwestdata[key], southeastdata[key], southwestdata[key]]
    idx = tmp.index(min(tmp))
    if idx == 0:
        new_midwest.append(key)
    elif idx == 1:
        new_southeast.append(key)
    elif idx == 2:
        new_southwest.append(key)
#     elif idx == 3:
#         new_northwest.append(key)
#     else:
#         new_southwest.append(key)
#new_west.sort()
new_midwest.sort()
new_southwest.sort()
#new_northwest.sort()
new_southeast.sort()
# if (west == new_west and midwest == new_midwest and southeast == new_southeast and southwest == new_southwest and northeast == new_northwest):
#     flag = 0
# else:
#     west = new_west
#     midwest = new_midwest
#     southeast = new_southeast
#     southwest = new_southwest
#     northeast = new_northwest
#print "west includes:", new_west
print "midwest includes:", new_midwest
print "southeast includes:", new_southeast
#print "northeast includes:", new_northeast
print "southwest includes:", new_southwest
print midwest == new_midwest
print southeast == new_southeast
print southwest == new_southwest
print len(midwest) + len(southwest) + len(southeast)
# Out:
# midwest includes: ['AK', 'CO', 'CT', 'DC', 'DE', 'HI', 'IA', 'IL', 'IN', 'KS', 'MA', 'MD', 'ME', 'MN', 'MT', 'ND', 'NE', 'NH', 'NJ', 'NY', 'OH', 'PA', 'RI', 'SD', 'UT', 'VA', 'WA', 'WI', 'WY']
# southeast includes: ['AL', 'AR', 'AZ', 'CA', 'FL', 'GA', 'ID', 'KY', 'LA', 'MI', 'MO', 'MS', 'NC', 'NM', 'NV', 'OK', 'OR', 'SC', 'TN', 'TX', 'WV']
# southwest includes: ['VT']
# False
# False
# False
# 51

# %%
midwest = new_midwest
southwest = new_southwest
southeast = new_southeast
#west = ['AK', 'CA', 'CO', 'HI', 'ID', 'MT', 'NV', 'OR', 'UT', 'WA', 'WY']
#midwest = ['AK', 'CO', 'CT', 'DE', 'HI', 'IA', 'IL', 'IN', 'KS', 'MA', 'MD', 'ME', 'MI', 'MN', 'MT', 'ND', 'NE', 'NH', 'NY', 'OH', 'PA', 'RI', 'SD', 'UT', 'VA', 'VT', 'WA', 'WI', 'WY']
#southwest = ['MA', 'VT']
#southeast = ['AL', 'AR', 'AZ', 'CA', 'FL', 'GA', 'ID', 'KY', 'LA', 'MO', 'MS', 'NC', 'NM', 'NV', 'OK', 'OR', 'SC', 'TN', 'TX', 'WV']
#northeast = ['CT', 'DE', 'ME', 'MD', 'MA', 'NH', 'NH', 'NY', 'PA', 'RI', 'VT']
#west.sort()
midwest.sort()
southwest.sort()
southeast.sort()
#northeast.sort()
#west_coef, west_incept = 0, 0
midwest_coef, midwest_incept = 0, 0
southeast_coef, southeast_incept = 0, 0
#northeast_coef, northeast_incept = 0, 0
southwest_coef, southwest_incept = 0, 0
#westdata = dict()
midwestdata = dict()
southeastdata = dict()
#northeastdata = dict()
southwestdata = dict()
allstates = midwest + southeast + southwest
for state in allstates:
    #westdata[state] = 0
    midwestdata[state] = 0
    southeastdata[state] = 0
    #northeastdata[state] = 0
    southwestdata[state] = 0
#west_coef, west_incept = regs(west)
midwest_coef, midwest_incept = regs(midwest)
southwest_coef, southwest_incept = regs(southwest)
southeast_coef, southeast_incept = regs(southeast)
#northeast_coef, northeast_incept = regs(northeast)
for row in whole:
    if row[4] in westdata.keys():
#        westdata[row[4]] += abs(float(row[6]) * west_coef - float(row[8]) + west_incept) / math.sqrt(float(west_coef) ** 2 + 1)
        midwestdata[row[4]] += abs(float(row[6]) * midwest_coef - float(row[8]) + midwest_incept) / math.sqrt(float(midwest_coef) ** 2 + 1)
        southeastdata[row[4]] += abs(float(row[6]) * southeast_coef - float(row[8]) + southeast_incept) / math.sqrt(float(southeast_coef) ** 2 + 1)
#        northeastdata[row[4]] += abs(float(row[6]) * northeast_coef - float(row[8]) + northeast_incept) / math.sqrt(float(northeast_coef) ** 2 + 1)
        southwestdata[row[4]] += abs(float(row[6]) * southwest_coef - float(row[8]) + northeast_incept) / math.sqrt(float(southwest_coef) ** 2 + 1)
#new_west = []
new_midwest = []
new_southwest = []
#new_northeast = []
new_southeast = []
for key in westdata.keys():
    tmp = [midwestdata[key], southeastdata[key], southwestdata[key]]
    idx = tmp.index(min(tmp))
    if idx == 0:
        new_midwest.append(key)
    elif idx == 1:
        new_southeast.append(key)
    elif idx == 2:
        new_southwest.append(key)
#     elif idx == 3:
#         new_northwest.append(key)
#     else:
#         new_southwest.append(key)
#new_west.sort()
new_midwest.sort()
new_southwest.sort()
#new_northwest.sort()
new_southeast.sort()
# if (west == new_west and midwest == new_midwest and southeast == new_southeast and southwest == new_southwest and northeast == new_northwest):
#     flag = 0
# else:
#     west = new_west
#     midwest = new_midwest
#     southeast = new_southeast
#     southwest = new_southwest
#     northeast = new_northwest
#print "west includes:", new_west
print "midwest includes:", new_midwest
print "southeast includes:", new_southeast
#print "northeast includes:", new_northeast
print "southwest includes:", new_southwest
print midwest == new_midwest
print southeast == new_southeast
print southwest == new_southwest
print len(midwest) + len(southwest) + len(southeast)
# Out:
# midwest includes: ['IL', 'IN', 'KS', 'NJ', 'NY', 'OH']
# southeast includes: ['AL', 'AR', 'AZ', 'CA', 'FL', 'GA', 'ID', 'KY', 'LA', 'MI', 'MO', 'MS', 'NC', 'NM', 'NV', 'OK', 'OR', 'SC', 'TN', 'TX', 'WV']
# southwest includes: ['AK', 'CO', 'CT', 'DC', 'DE', 'HI', 'IA', 'MA', 'MD', 'ME', 'MN', 'MT', 'ND', 'NE', 'NH', 'PA', 'RI', 'SD', 'UT', 'VA', 'VT', 'WA', 'WI', 'WY']
# False
# True
# False
# 51

# %%
midwest = new_midwest
southwest = new_southwest
southeast = new_southeast
#west = ['AK', 'CA', 'CO', 'HI', 'ID', 'MT', 'NV', 'OR', 'UT', 'WA', 'WY']
#midwest = ['AK', 'CO', 'CT', 'DE', 'HI', 'IA', 'IL', 'IN', 'KS', 'MA', 'MD', 'ME', 'MI', 'MN', 'MT', 'ND', 'NE', 'NH', 'NY', 'OH', 'PA', 'RI', 'SD', 'UT', 'VA', 'VT', 'WA', 'WI', 'WY']
#southwest = ['MA', 'VT']
#southeast = ['AL', 'AR', 'AZ', 'CA', 'FL', 'GA', 'ID', 'KY', 'LA', 'MO', 'MS', 'NC', 'NM', 'NV', 'OK', 'OR', 'SC', 'TN', 'TX', 'WV']
#northeast = ['CT', 'DE', 'ME', 'MD', 'MA', 'NH', 'NH', 'NY', 'PA', 'RI', 'VT']
#west.sort()
midwest.sort()
southwest.sort()
southeast.sort()
#northeast.sort()
#west_coef, west_incept = 0, 0
midwest_coef, midwest_incept = 0, 0
southeast_coef, southeast_incept = 0, 0
#northeast_coef, northeast_incept = 0, 0
southwest_coef, southwest_incept = 0, 0
#westdata = dict()
midwestdata = dict()
southeastdata = dict()
#northeastdata = dict()
southwestdata = dict()
allstates = midwest + southeast + southwest
for state in allstates:
    #westdata[state] = 0
    midwestdata[state] = 0
    southeastdata[state] = 0
    #northeastdata[state] = 0
    southwestdata[state] = 0
#west_coef, west_incept = regs(west)
midwest_coef, midwest_incept = regs(midwest)
southwest_coef, southwest_incept = regs(southwest)
southeast_coef, southeast_incept = regs(southeast)
#northeast_coef, northeast_incept = regs(northeast)
for row in whole:
    if row[4] in westdata.keys():
#        westdata[row[4]] += abs(float(row[6]) * west_coef - float(row[8]) + west_incept) / math.sqrt(float(west_coef) ** 2 + 1)
        midwestdata[row[4]] += abs(float(row[6]) * midwest_coef - float(row[8]) + midwest_incept) / math.sqrt(float(midwest_coef) ** 2 + 1)
        southeastdata[row[4]] += abs(float(row[6]) * southeast_coef - float(row[8]) + southeast_incept) / math.sqrt(float(southeast_coef) ** 2 + 1)
#        northeastdata[row[4]] += abs(float(row[6]) * northeast_coef - float(row[8]) + northeast_incept) / math.sqrt(float(northeast_coef) ** 2 + 1)
        southwestdata[row[4]] += abs(float(row[6]) * southwest_coef - float(row[8]) + northeast_incept) / math.sqrt(float(southwest_coef) ** 2 + 1)
#new_west = []
new_midwest = []
new_southwest = []
#new_northeast = []
new_southeast = []
for key in westdata.keys():
    tmp = [midwestdata[key], southeastdata[key], southwestdata[key]]
    idx = tmp.index(min(tmp))
    if idx == 0:
        new_midwest.append(key)
    elif idx == 1:
        new_southeast.append(key)
    elif idx == 2:
        new_southwest.append(key)
#     elif idx == 3:
#         new_northwest.append(key)
#     else:
#         new_southwest.append(key)
#new_west.sort()
new_midwest.sort()
new_southwest.sort()
#new_northwest.sort()
new_southeast.sort()
# if (west == new_west and midwest == new_midwest and southeast == new_southeast and southwest == new_southwest and northeast == new_northwest):
#     flag = 0
# else:
#     west = new_west
#     midwest = new_midwest
#     southeast = new_southeast
#     southwest = new_southwest
#     northeast = new_northwest
#print "west includes:", new_west
print "midwest includes:", new_midwest
print "southeast includes:", new_southeast
#print "northeast includes:", new_northeast
print "southwest includes:", new_southwest
print midwest == new_midwest
print southeast == new_southeast
print southwest == new_southwest
print len(midwest) + len(southwest) + len(southeast)
# Out:
# midwest includes: ['AK', 'CO', 'HI', 'IL', 'IN', 'KS', 'ME', 'MI', 'MT', 'NJ', 'NY', 'OH', 'PA', 'SD', 'VA', 'WA', 'WY']
# southeast includes: ['AL', 'AR', 'AZ', 'CA', 'FL', 'GA', 'ID', 'KY', 'LA', 'MO', 'MS', 'NC', 'NM', 'NV', 'OK', 'OR', 'SC', 'TN', 'TX', 'WV']
# southwest includes: ['CT', 'DC', 'DE', 'IA', 'MA', 'MD', 'MN', 'ND', 'NE', 'NH', 'RI', 'UT', 'VT', 'WI']
# False
# False
# False
# 51

# %%
midwest = new_midwest
southwest = new_southwest
southeast = new_southeast
#west = ['AK', 'CA', 'CO', 'HI', 'ID', 'MT', 'NV', 'OR', 'UT', 'WA', 'WY']
#midwest = ['AK', 'CO', 'CT', 'DE', 'HI', 'IA', 'IL', 'IN', 'KS', 'MA', 'MD', 'ME', 'MI', 'MN', 'MT', 'ND', 'NE', 'NH', 'NY', 'OH', 'PA', 'RI', 'SD', 'UT', 'VA', 'VT', 'WA', 'WI', 'WY']
#southwest = ['MA', 'VT']
#southeast = ['AL', 'AR', 'AZ', 'CA', 'FL', 'GA', 'ID', 'KY', 'LA', 'MO', 'MS', 'NC', 'NM', 'NV', 'OK', 'OR', 'SC', 'TN', 'TX', 'WV']
#northeast = ['CT', 'DE', 'ME', 'MD', 'MA', 'NH', 'NH', 'NY', 'PA', 'RI', 'VT']
#west.sort()
midwest.sort()
southwest.sort()
southeast.sort()
#northeast.sort()
#west_coef, west_incept = 0, 0
midwest_coef, midwest_incept = 0, 0
southeast_coef, southeast_incept = 0, 0
#northeast_coef, northeast_incept = 0, 0
southwest_coef, southwest_incept = 0, 0
#westdata = dict()
midwestdata = dict()
southeastdata = dict()
#northeastdata = dict()
southwestdata = dict()
allstates = midwest + southeast + southwest
for state in allstates:
    #westdata[state] = 0
    midwestdata[state] = 0
    southeastdata[state] = 0
    #northeastdata[state] = 0
    southwestdata[state] = 0
#west_coef, west_incept = regs(west)
midwest_coef, midwest_incept = regs(midwest)
southwest_coef, southwest_incept = regs(southwest)
southeast_coef, southeast_incept = regs(southeast)
#northeast_coef, northeast_incept = regs(northeast)
for row in whole:
    if row[4] in westdata.keys():
#        westdata[row[4]] += abs(float(row[6]) * west_coef - float(row[8]) + west_incept) / math.sqrt(float(west_coef) ** 2 + 1)
        midwestdata[row[4]] += abs(float(row[6]) * midwest_coef - float(row[8]) + midwest_incept) / math.sqrt(float(midwest_coef) ** 2 + 1)
        southeastdata[row[4]] += abs(float(row[6]) * southeast_coef - float(row[8]) + southeast_incept) / math.sqrt(float(southeast_coef) ** 2 + 1)
#        northeastdata[row[4]] += abs(float(row[6]) * northeast_coef - float(row[8]) + northeast_incept) / math.sqrt(float(northeast_coef) ** 2 + 1)
        southwestdata[row[4]] += abs(float(row[6]) * southwest_coef - float(row[8]) + northeast_incept) / math.sqrt(float(southwest_coef) ** 2 + 1)
#new_west = []
new_midwest = []
new_southwest = []
#new_northeast = []
new_southeast = []
for key in westdata.keys():
    tmp = [midwestdata[key], southeastdata[key], southwestdata[key]]
    idx = tmp.index(min(tmp))
    if idx == 0:
        new_midwest.append(key)
    elif idx == 1:
        new_southeast.append(key)
    elif idx == 2:
        new_southwest.append(key)
#     elif idx == 3:
#         new_northwest.append(key)
#     else:
#         new_southwest.append(key)
#new_west.sort()
new_midwest.sort()
new_southwest.sort()
#new_northwest.sort()
new_southeast.sort()
# if (west == new_west and midwest == new_midwest and southeast == new_southeast and southwest == new_southwest and northeast == new_northwest):
#     flag = 0
# else:
#     west = new_west
#     midwest = new_midwest
#     southeast = new_southeast
#     southwest = new_southwest
#     northeast = new_northwest
#print "west includes:", new_west
print "midwest includes:", new_midwest
print "southeast includes:", new_southeast
#print "northeast includes:", new_northeast
print "southwest includes:", new_southwest
print midwest == new_midwest
print southeast == new_southeast
print southwest == new_southwest
print len(midwest) + len(southwest) + len(southeast)
# Out:
# midwest includes: ['AK', 'CO', 'DC', 'DE', 'HI', 'IL', 'IN', 'KS', 'MD', 'ME', 'MI', 'MN', 'MO', 'MT', 'ND', 'NJ', 'NY', 'OH', 'PA', 'SD', 'UT', 'VA', 'WA', 'WY']
# southeast includes: ['AL', 'AR', 'AZ', 'CA', 'FL', 'GA', 'ID', 'KY', 'LA', 'MS', 'NC', 'NM', 'NV', 'OK', 'OR', 'SC', 'TN', 'TX', 'WV']
# southwest includes: ['CT', 'IA', 'MA', 'NE', 'NH', 'RI', 'VT', 'WI']
# False
# False
# False
# 51

# %%
midwest = new_midwest
southwest = new_southwest
southeast = new_southeast
#west = ['AK', 'CA', 'CO', 'HI', 'ID', 'MT', 'NV', 'OR', 'UT', 'WA', 'WY']
#midwest = ['AK', 'CO', 'CT', 'DE', 'HI', 'IA', 'IL', 'IN', 'KS', 'MA', 'MD', 'ME', 'MI', 'MN', 'MT', 'ND', 'NE', 'NH', 'NY', 'OH', 'PA', 'RI', 'SD', 'UT', 'VA', 'VT', 'WA', 'WI', 'WY']
#southwest = ['MA', 'VT']
#southeast = ['AL', 'AR', 'AZ', 'CA', 'FL', 'GA', 'ID', 'KY', 'LA', 'MO', 'MS', 'NC', 'NM', 'NV', 'OK', 'OR', 'SC', 'TN', 'TX', 'WV']
#northeast = ['CT', 'DE', 'ME', 'MD', 'MA', 'NH', 'NH', 'NY', 'PA', 'RI', 'VT']
#west.sort()
midwest.sort()
southwest.sort()
southeast.sort()
#northeast.sort()
#west_coef, west_incept = 0, 0
midwest_coef, midwest_incept = 0, 0
southeast_coef, southeast_incept = 0, 0
#northeast_coef, northeast_incept = 0, 0
southwest_coef, southwest_incept = 0, 0
#westdata = dict()
midwestdata = dict()
southeastdata = dict()
#northeastdata = dict()
southwestdata = dict()
allstates = midwest + southeast + southwest
for state in allstates:
    #westdata[state] = 0
    midwestdata[state] = 0
    southeastdata[state] = 0
    #northeastdata[state] = 0
    southwestdata[state] = 0
#west_coef, west_incept = regs(west)
midwest_coef, midwest_incept = regs(midwest)
southwest_coef, southwest_incept = regs(southwest)
southeast_coef, southeast_incept = regs(southeast)
#northeast_coef, northeast_incept = regs(northeast)
for row in whole:
    if row[4] in westdata.keys():
#        westdata[row[4]] += abs(float(row[6]) * west_coef - float(row[8]) + west_incept) / math.sqrt(float(west_coef) ** 2 + 1)
        midwestdata[row[4]] += abs(float(row[6]) * midwest_coef - float(row[8]) + midwest_incept) / math.sqrt(float(midwest_coef) ** 2 + 1)
        southeastdata[row[4]] += abs(float(row[6]) * southeast_coef - float(row[8]) + southeast_incept) / math.sqrt(float(southeast_coef) ** 2 + 1)
#        northeastdata[row[4]] += abs(float(row[6]) * northeast_coef - float(row[8]) + northeast_incept) / math.sqrt(float(northeast_coef) ** 2 + 1)
        southwestdata[row[4]] += abs(float(row[6]) * southwest_coef - float(row[8]) + northeast_incept) / math.sqrt(float(southwest_coef) ** 2 + 1)
#new_west = []
new_midwest = []
new_southwest = []
#new_northeast = []
new_southeast = []
for key in westdata.keys():
    tmp = [midwestdata[key], southeastdata[key], southwestdata[key]]
    idx = tmp.index(min(tmp))
    if idx == 0:
        new_midwest.append(key)
    elif idx == 1:
        new_southeast.append(key)
    elif idx == 2:
        new_southwest.append(key)
#     elif idx == 3:
#         new_northwest.append(key)
#     else:
#         new_southwest.append(key)
#new_west.sort()
new_midwest.sort()
new_southwest.sort()
#new_northwest.sort()
new_southeast.sort()
# if (west == new_west and midwest == new_midwest and southeast == new_southeast and southwest == new_southwest and northeast == new_northwest):
#     flag = 0
# else:
#     west = new_west
#     midwest = new_midwest
#     southeast = new_southeast
#     southwest = new_southwest
#     northeast = new_northwest
#print "west includes:", new_west
print "midwest includes:", new_midwest
print "southeast includes:", new_southeast
#print "northeast includes:", new_northeast
print "southwest includes:", new_southwest
print midwest == new_midwest
print southeast == new_southeast
print southwest == new_southwest
print len(midwest) + len(southwest) + len(southeast)
# Out:
# midwest includes: ['AK', 'CO', 'CT', 'DC', 'DE', 'HI', 'IL', 'IN', 'KS', 'MD', 'ME', 'MI', 'MN', 'MT', 'ND', 'NE', 'NH', 'NJ', 'NY', 'OH', 'PA', 'RI', 'SD', 'UT', 'VA', 'WA', 'WI', 'WY']
# southeast includes: ['AL', 'AR', 'AZ', 'CA', 'FL', 'GA', 'ID', 'KY', 'LA', 'MO', 'MS', 'NC', 'NM', 'NV', 'OK', 'OR', 'SC', 'TN', 'TX', 'WV']
# southwest includes: ['IA', 'MA', 'VT']
# False
# False
# False
# 51

# %%
midwest = new_midwest
southwest = new_southwest
southeast = new_southeast
#west = ['AK', 'CA', 'CO', 'HI', 'ID', 'MT', 'NV', 'OR', 'UT', 'WA', 'WY']
#midwest = ['AK', 'CO', 'CT', 'DE', 'HI', 'IA', 'IL', 'IN', 'KS', 'MA', 'MD', 'ME', 'MI', 'MN', 'MT', 'ND', 'NE', 'NH', 'NY', 'OH', 'PA', 'RI', 'SD', 'UT', 'VA', 'VT', 'WA', 'WI', 'WY']
#southwest = ['MA', 'VT']
#southeast = ['AL', 'AR', 'AZ', 'CA', 'FL', 'GA', 'ID', 'KY', 'LA', 'MO', 'MS', 'NC', 'NM', 'NV', 'OK', 'OR', 'SC', 'TN', 'TX', 'WV']
#northeast = ['CT', 'DE', 'ME', 'MD', 'MA', 'NH', 'NH', 'NY', 'PA', 'RI', 'VT']
#west.sort()
midwest.sort()
southwest.sort()
southeast.sort()
#northeast.sort()
#west_coef, west_incept = 0, 0
midwest_coef, midwest_incept = 0, 0
southeast_coef, southeast_incept = 0, 0
#northeast_coef, northeast_incept = 0, 0
southwest_coef, southwest_incept = 0, 0
#westdata = dict()
midwestdata = dict()
southeastdata = dict()
#northeastdata = dict()
southwestdata = dict()
allstates = midwest + southeast + southwest
for state in allstates:
    #westdata[state] = 0
    midwestdata[state] = 0
    southeastdata[state] = 0
    #northeastdata[state] = 0
    southwestdata[state] = 0
#west_coef, west_incept = regs(west)
midwest_coef, midwest_incept = regs(midwest)
southwest_coef, southwest_incept = regs(southwest)
southeast_coef, southeast_incept = regs(southeast)
#northeast_coef, northeast_incept = regs(northeast)
for row in whole:
    if row[4] in westdata.keys():
#        westdata[row[4]] += abs(float(row[6]) * west_coef - float(row[8]) + west_incept) / math.sqrt(float(west_coef) ** 2 + 1)
        midwestdata[row[4]] += abs(float(row[6]) * midwest_coef - float(row[8]) + midwest_incept) / math.sqrt(float(midwest_coef) ** 2 + 1)
        southeastdata[row[4]] += abs(float(row[6]) * southeast_coef - float(row[8]) + southeast_incept) / math.sqrt(float(southeast_coef) ** 2 + 1)
#        northeastdata[row[4]] += abs(float(row[6]) * northeast_coef - float(row[8]) + northeast_incept) / math.sqrt(float(northeast_coef) ** 2 + 1)
        southwestdata[row[4]] += abs(float(row[6]) * southwest_coef - float(row[8]) + northeast_incept) / math.sqrt(float(southwest_coef) ** 2 + 1)
#new_west = []
new_midwest = []
new_southwest = []
#new_northeast = []
new_southeast = []
for key in westdata.keys():
    tmp = [midwestdata[key], southeastdata[key], southwestdata[key]]
    idx = tmp.index(min(tmp))
    if idx == 0:
        new_midwest.append(key)
    elif idx == 1:
        new_southeast.append(key)
    elif idx == 2:
        new_southwest.append(key)
#     elif idx == 3:
#         new_northwest.append(key)
#     else:
#         new_southwest.append(key)
#new_west.sort()
new_midwest.sort()
new_southwest.sort()
#new_northwest.sort()
new_southeast.sort()
# if (west == new_west and midwest == new_midwest and southeast == new_southeast and southwest == new_southwest and northeast == new_northwest):
#     flag = 0
# else:
#     west = new_west
#     midwest = new_midwest
#     southeast = new_southeast
#     southwest = new_southwest
#     northeast = new_northwest
#print "west includes:", new_west
print "midwest includes:", new_midwest
print "southeast includes:", new_southeast
#print "northeast includes:", new_northeast
print "southwest includes:", new_southwest
print midwest == new_midwest
print southeast == new_southeast
print southwest == new_southwest
print len(midwest) + len(southwest) + len(southeast)
# Out:
# midwest includes: ['AK', 'CO', 'CT', 'DC', 'DE', 'HI', 'IA', 'IL', 'IN', 'KS', 'MA', 'MD', 'ME', 'MN', 'MT', 'ND', 'NE', 'NH', 'NJ', 'NY', 'OH', 'PA', 'RI', 'SD', 'UT', 'VA', 'WA', 'WI', 'WY']
# southeast includes: ['AL', 'AR', 'AZ', 'CA', 'FL', 'GA', 'ID', 'KY', 'LA', 'MI', 'MO', 'MS', 'NC', 'NM', 'NV', 'OK', 'OR', 'SC', 'TN', 'TX', 'WV']
# southwest includes: ['VT']
# False
# False
# False
# 51

# %%
midwest = new_midwest
southwest = new_southwest
southeast = new_southeast
#west = ['AK', 'CA', 'CO', 'HI', 'ID', 'MT', 'NV', 'OR', 'UT', 'WA', 'WY']
#midwest = ['AK', 'CO', 'CT', 'DE', 'HI', 'IA', 'IL', 'IN', 'KS', 'MA', 'MD', 'ME', 'MI', 'MN', 'MT', 'ND', 'NE', 'NH', 'NY', 'OH', 'PA', 'RI', 'SD', 'UT', 'VA', 'VT', 'WA', 'WI', 'WY']
#southwest = ['MA', 'VT']
#southeast = ['AL', 'AR', 'AZ', 'CA', 'FL', 'GA', 'ID', 'KY', 'LA', 'MO', 'MS', 'NC', 'NM', 'NV', 'OK', 'OR', 'SC', 'TN', 'TX', 'WV']
#northeast = ['CT', 'DE', 'ME', 'MD', 'MA', 'NH', 'NH', 'NY', 'PA', 'RI', 'VT']
#west.sort()
midwest.sort()
southwest.sort()
southeast.sort()
#northeast.sort()
#west_coef, west_incept = 0, 0
midwest_coef, midwest_incept = 0, 0
southeast_coef, southeast_incept = 0, 0
#northeast_coef, northeast_incept = 0, 0
southwest_coef, southwest_incept = 0, 0
#westdata = dict()
midwestdata = dict()
southeastdata = dict()
#northeastdata = dict()
southwestdata = dict()
allstates = midwest + southeast + southwest
for state in allstates:
    #westdata[state] = 0
    midwestdata[state] = 0
    southeastdata[state] = 0
    #northeastdata[state] = 0
    southwestdata[state] = 0
#west_coef, west_incept = regs(west)
midwest_coef, midwest_incept = regs(midwest)
southwest_coef, southwest_incept = regs(southwest)
southeast_coef, southeast_incept = regs(southeast)
#northeast_coef, northeast_incept = regs(northeast)
for row in whole:
    if row[4] in westdata.keys():
#        westdata[row[4]] += abs(float(row[6]) * west_coef - float(row[8]) + west_incept) / math.sqrt(float(west_coef) ** 2 + 1)
        midwestdata[row[4]] += abs(float(row[6]) * midwest_coef - float(row[8]) + midwest_incept) / math.sqrt(float(midwest_coef) ** 2 + 1)
        southeastdata[row[4]] += abs(float(row[6]) * southeast_coef - float(row[8]) + southeast_incept) / math.sqrt(float(southeast_coef) ** 2 + 1)
#        northeastdata[row[4]] += abs(float(row[6]) * northeast_coef - float(row[8]) + northeast_incept) / math.sqrt(float(northeast_coef) ** 2 + 1)
        southwestdata[row[4]] += abs(float(row[6]) * southwest_coef - float(row[8]) + northeast_incept) / math.sqrt(float(southwest_coef) ** 2 + 1)
#new_west = []
new_midwest = []
new_southwest = []
#new_northeast = []
new_southeast = []
for key in westdata.keys():
    tmp = [midwestdata[key], southeastdata[key], southwestdata[key]]
    idx = tmp.index(min(tmp))
    if idx == 0:
        new_midwest.append(key)
    elif idx == 1:
        new_southeast.append(key)
    elif idx == 2:
        new_southwest.append(key)
#     elif idx == 3:
#         new_northwest.append(key)
#     else:
#         new_southwest.append(key)
#new_west.sort()
new_midwest.sort()
new_southwest.sort()
#new_northwest.sort()
new_southeast.sort()
# if (west == new_west and midwest == new_midwest and southeast == new_southeast and southwest == new_southwest and northeast == new_northwest):
#     flag = 0
# else:
#     west = new_west
#     midwest = new_midwest
#     southeast = new_southeast
#     southwest = new_southwest
#     northeast = new_northwest
#print "west includes:", new_west
print "midwest includes:", new_midwest
print "southeast includes:", new_southeast
#print "northeast includes:", new_northeast
print "southwest includes:", new_southwest
print midwest == new_midwest
print southeast == new_southeast
print southwest == new_southwest
print len(midwest) + len(southwest) + len(southeast)
# Out:
# midwest includes: ['IL', 'IN', 'KS', 'NJ', 'NY', 'OH']
# southeast includes: ['AL', 'AR', 'AZ', 'CA', 'FL', 'GA', 'ID', 'KY', 'LA', 'MI', 'MO', 'MS', 'NC', 'NM', 'NV', 'OK', 'OR', 'SC', 'TN', 'TX', 'WV']
# southwest includes: ['AK', 'CO', 'CT', 'DC', 'DE', 'HI', 'IA', 'MA', 'MD', 'ME', 'MN', 'MT', 'ND', 'NE', 'NH', 'PA', 'RI', 'SD', 'UT', 'VA', 'VT', 'WA', 'WI', 'WY']
# False
# True
# False
# 51

# %%
midwest = new_midwest
southwest = new_southwest
southeast = new_southeast
#west = ['AK', 'CA', 'CO', 'HI', 'ID', 'MT', 'NV', 'OR', 'UT', 'WA', 'WY']
#midwest = ['AK', 'CO', 'CT', 'DE', 'HI', 'IA', 'IL', 'IN', 'KS', 'MA', 'MD', 'ME', 'MI', 'MN', 'MT', 'ND', 'NE', 'NH', 'NY', 'OH', 'PA', 'RI', 'SD', 'UT', 'VA', 'VT', 'WA', 'WI', 'WY']
#southwest = ['MA', 'VT']
#southeast = ['AL', 'AR', 'AZ', 'CA', 'FL', 'GA', 'ID', 'KY', 'LA', 'MO', 'MS', 'NC', 'NM', 'NV', 'OK', 'OR', 'SC', 'TN', 'TX', 'WV']
#northeast = ['CT', 'DE', 'ME', 'MD', 'MA', 'NH', 'NH', 'NY', 'PA', 'RI', 'VT']
#west.sort()
midwest.sort()
southwest.sort()
southeast.sort()
#northeast.sort()
#west_coef, west_incept = 0, 0
midwest_coef, midwest_incept = 0, 0
southeast_coef, southeast_incept = 0, 0
#northeast_coef, northeast_incept = 0, 0
southwest_coef, southwest_incept = 0, 0
#westdata = dict()
midwestdata = dict()
southeastdata = dict()
#northeastdata = dict()
southwestdata = dict()
allstates = midwest + southeast + southwest
for state in allstates:
    #westdata[state] = 0
    midwestdata[state] = 0
    southeastdata[state] = 0
    #northeastdata[state] = 0
    southwestdata[state] = 0
#west_coef, west_incept = regs(west)
midwest_coef, midwest_incept = regs(midwest)
southwest_coef, southwest_incept = regs(southwest)
southeast_coef, southeast_incept = regs(southeast)
#northeast_coef, northeast_incept = regs(northeast)
for row in whole:
    if row[4] in westdata.keys():
#        westdata[row[4]] += abs(float(row[6]) * west_coef - float(row[8]) + west_incept) / math.sqrt(float(west_coef) ** 2 + 1)
        midwestdata[row[4]] += abs(float(row[6]) * midwest_coef - float(row[8]) + midwest_incept) / math.sqrt(float(midwest_coef) ** 2 + 1)
        southeastdata[row[4]] += abs(float(row[6]) * southeast_coef - float(row[8]) + southeast_incept) / math.sqrt(float(southeast_coef) ** 2 + 1)
#        northeastdata[row[4]] += abs(float(row[6]) * northeast_coef - float(row[8]) + northeast_incept) / math.sqrt(float(northeast_coef) ** 2 + 1)
        southwestdata[row[4]] += abs(float(row[6]) * southwest_coef - float(row[8]) + northeast_incept) / math.sqrt(float(southwest_coef) ** 2 + 1)
#new_west = []
new_midwest = []
new_southwest = []
#new_northeast = []
new_southeast = []
for key in westdata.keys():
    tmp = [midwestdata[key], southeastdata[key], southwestdata[key]]
    idx = tmp.index(min(tmp))
    if idx == 0:
        new_midwest.append(key)
    elif idx == 1:
        new_southeast.append(key)
    elif idx == 2:
        new_southwest.append(key)
#     elif idx == 3:
#         new_northwest.append(key)
#     else:
#         new_southwest.append(key)
#new_west.sort()
new_midwest.sort()
new_southwest.sort()
#new_northwest.sort()
new_southeast.sort()
# if (west == new_west and midwest == new_midwest and southeast == new_southeast and southwest == new_southwest and northeast == new_northwest):
#     flag = 0
# else:
#     west = new_west
#     midwest = new_midwest
#     southeast = new_southeast
#     southwest = new_southwest
#     northeast = new_northwest
#print "west includes:", new_west
print "midwest includes:", new_midwest
print "southeast includes:", new_southeast
#print "northeast includes:", new_northeast
print "southwest includes:", new_southwest
print midwest == new_midwest
print southeast == new_southeast
print southwest == new_southwest
print len(midwest) + len(southwest) + len(southeast)
# Out:
# midwest includes: ['AK', 'CO', 'HI', 'IL', 'IN', 'KS', 'ME', 'MI', 'MT', 'NJ', 'NY', 'OH', 'PA', 'SD', 'VA', 'WA', 'WY']
# southeast includes: ['AL', 'AR', 'AZ', 'CA', 'FL', 'GA', 'ID', 'KY', 'LA', 'MO', 'MS', 'NC', 'NM', 'NV', 'OK', 'OR', 'SC', 'TN', 'TX', 'WV']
# southwest includes: ['CT', 'DC', 'DE', 'IA', 'MA', 'MD', 'MN', 'ND', 'NE', 'NH', 'RI', 'UT', 'VT', 'WI']
# False
# False
# False
# 51

# %%
midwest = new_midwest
southwest = new_southwest
southeast = new_southeast
#west = ['AK', 'CA', 'CO', 'HI', 'ID', 'MT', 'NV', 'OR', 'UT', 'WA', 'WY']
#midwest = ['AK', 'CO', 'CT', 'DE', 'HI', 'IA', 'IL', 'IN', 'KS', 'MA', 'MD', 'ME', 'MI', 'MN', 'MT', 'ND', 'NE', 'NH', 'NY', 'OH', 'PA', 'RI', 'SD', 'UT', 'VA', 'VT', 'WA', 'WI', 'WY']
#southwest = ['MA', 'VT']
#southeast = ['AL', 'AR', 'AZ', 'CA', 'FL', 'GA', 'ID', 'KY', 'LA', 'MO', 'MS', 'NC', 'NM', 'NV', 'OK', 'OR', 'SC', 'TN', 'TX', 'WV']
#northeast = ['CT', 'DE', 'ME', 'MD', 'MA', 'NH', 'NH', 'NY', 'PA', 'RI', 'VT']
#west.sort()
midwest.sort()
southwest.sort()
southeast.sort()
#northeast.sort()
#west_coef, west_incept = 0, 0
midwest_coef, midwest_incept = 0, 0
southeast_coef, southeast_incept = 0, 0
#northeast_coef, northeast_incept = 0, 0
southwest_coef, southwest_incept = 0, 0
#westdata = dict()
midwestdata = dict()
southeastdata = dict()
#northeastdata = dict()
southwestdata = dict()
allstates = midwest + southeast + southwest
for state in allstates:
    #westdata[state] = 0
    midwestdata[state] = 0
    southeastdata[state] = 0
    #northeastdata[state] = 0
    southwestdata[state] = 0
#west_coef, west_incept = regs(west)
midwest_coef, midwest_incept = regs(midwest)
southwest_coef, southwest_incept = regs(southwest)
southeast_coef, southeast_incept = regs(southeast)
#northeast_coef, northeast_incept = regs(northeast)
for row in whole:
    if row[4] in westdata.keys():
#        westdata[row[4]] += abs(float(row[6]) * west_coef - float(row[8]) + west_incept) / math.sqrt(float(west_coef) ** 2 + 1)
        midwestdata[row[4]] += abs(float(row[6]) * midwest_coef - float(row[8]) + midwest_incept) / math.sqrt(float(midwest_coef) ** 2 + 1)
        southeastdata[row[4]] += abs(float(row[6]) * southeast_coef - float(row[8]) + southeast_incept) / math.sqrt(float(southeast_coef) ** 2 + 1)
#        northeastdata[row[4]] += abs(float(row[6]) * northeast_coef - float(row[8]) + northeast_incept) / math.sqrt(float(northeast_coef) ** 2 + 1)
        southwestdata[row[4]] += abs(float(row[6]) * southwest_coef - float(row[8]) + northeast_incept) / math.sqrt(float(southwest_coef) ** 2 + 1)
#new_west = []
new_midwest = []
new_southwest = []
#new_northeast = []
new_southeast = []
for key in westdata.keys():
    tmp = [midwestdata[key], southeastdata[key], southwestdata[key]]
    idx = tmp.index(min(tmp))
    if idx == 0:
        new_midwest.append(key)
    elif idx == 1:
        new_southeast.append(key)
    elif idx == 2:
        new_southwest.append(key)
#     elif idx == 3:
#         new_northwest.append(key)
#     else:
#         new_southwest.append(key)
#new_west.sort()
new_midwest.sort()
new_southwest.sort()
#new_northwest.sort()
new_southeast.sort()
# if (west == new_west and midwest == new_midwest and southeast == new_southeast and southwest == new_southwest and northeast == new_northwest):
#     flag = 0
# else:
#     west = new_west
#     midwest = new_midwest
#     southeast = new_southeast
#     southwest = new_southwest
#     northeast = new_northwest
#print "west includes:", new_west
print "midwest includes:", new_midwest
print "southeast includes:", new_southeast
#print "northeast includes:", new_northeast
print "southwest includes:", new_southwest
print midwest == new_midwest
print southeast == new_southeast
print southwest == new_southwest
print len(midwest) + len(southwest) + len(southeast)
# Out:
# midwest includes: ['AK', 'CO', 'DC', 'DE', 'HI', 'IL', 'IN', 'KS', 'MD', 'ME', 'MI', 'MN', 'MO', 'MT', 'ND', 'NJ', 'NY', 'OH', 'PA', 'SD', 'UT', 'VA', 'WA', 'WY']
# southeast includes: ['AL', 'AR', 'AZ', 'CA', 'FL', 'GA', 'ID', 'KY', 'LA', 'MS', 'NC', 'NM', 'NV', 'OK', 'OR', 'SC', 'TN', 'TX', 'WV']
# southwest includes: ['CT', 'IA', 'MA', 'NE', 'NH', 'RI', 'VT', 'WI']
# False
# False
# False
# 51

# %%
midwest = new_midwest
southwest = new_southwest
southeast = new_southeast
#west = ['AK', 'CA', 'CO', 'HI', 'ID', 'MT', 'NV', 'OR', 'UT', 'WA', 'WY']
#midwest = ['AK', 'CO', 'CT', 'DE', 'HI', 'IA', 'IL', 'IN', 'KS', 'MA', 'MD', 'ME', 'MI', 'MN', 'MT', 'ND', 'NE', 'NH', 'NY', 'OH', 'PA', 'RI', 'SD', 'UT', 'VA', 'VT', 'WA', 'WI', 'WY']
#southwest = ['MA', 'VT']
#southeast = ['AL', 'AR', 'AZ', 'CA', 'FL', 'GA', 'ID', 'KY', 'LA', 'MO', 'MS', 'NC', 'NM', 'NV', 'OK', 'OR', 'SC', 'TN', 'TX', 'WV']
#northeast = ['CT', 'DE', 'ME', 'MD', 'MA', 'NH', 'NH', 'NY', 'PA', 'RI', 'VT']
#west.sort()
midwest.sort()
southwest.sort()
southeast.sort()
#northeast.sort()
#west_coef, west_incept = 0, 0
midwest_coef, midwest_incept = 0, 0
southeast_coef, southeast_incept = 0, 0
#northeast_coef, northeast_incept = 0, 0
southwest_coef, southwest_incept = 0, 0
#westdata = dict()
midwestdata = dict()
southeastdata = dict()
#northeastdata = dict()
southwestdata = dict()
allstates = midwest + southeast + southwest
for state in allstates:
    #westdata[state] = 0
    midwestdata[state] = 0
    southeastdata[state] = 0
    #northeastdata[state] = 0
    southwestdata[state] = 0
#west_coef, west_incept = regs(west)
midwest_coef, midwest_incept = regs(midwest)
southwest_coef, southwest_incept = regs(southwest)
southeast_coef, southeast_incept = regs(southeast)
#northeast_coef, northeast_incept = regs(northeast)
for row in whole:
    if row[4] in westdata.keys():
#        westdata[row[4]] += abs(float(row[6]) * west_coef - float(row[8]) + west_incept) / math.sqrt(float(west_coef) ** 2 + 1)
        midwestdata[row[4]] += abs(float(row[6]) * midwest_coef - float(row[8]) + midwest_incept) / math.sqrt(float(midwest_coef) ** 2 + 1)
        southeastdata[row[4]] += abs(float(row[6]) * southeast_coef - float(row[8]) + southeast_incept) / math.sqrt(float(southeast_coef) ** 2 + 1)
#        northeastdata[row[4]] += abs(float(row[6]) * northeast_coef - float(row[8]) + northeast_incept) / math.sqrt(float(northeast_coef) ** 2 + 1)
        southwestdata[row[4]] += abs(float(row[6]) * southwest_coef - float(row[8]) + northeast_incept) / math.sqrt(float(southwest_coef) ** 2 + 1)
#new_west = []
new_midwest = []
new_southwest = []
#new_northeast = []
new_southeast = []
for key in westdata.keys():
    tmp = [midwestdata[key], southeastdata[key], southwestdata[key]]
    idx = tmp.index(min(tmp))
    if idx == 0:
        new_midwest.append(key)
    elif idx == 1:
        new_southeast.append(key)
    elif idx == 2:
        new_southwest.append(key)
#     elif idx == 3:
#         new_northwest.append(key)
#     else:
#         new_southwest.append(key)
#new_west.sort()
new_midwest.sort()
new_southwest.sort()
#new_northwest.sort()
new_southeast.sort()
# if (west == new_west and midwest == new_midwest and southeast == new_southeast and southwest == new_southwest and northeast == new_northwest):
#     flag = 0
# else:
#     west = new_west
#     midwest = new_midwest
#     southeast = new_southeast
#     southwest = new_southwest
#     northeast = new_northwest
#print "west includes:", new_west
print "midwest includes:", new_midwest
print "southeast includes:", new_southeast
#print "northeast includes:", new_northeast
print "southwest includes:", new_southwest
print midwest == new_midwest
print southeast == new_southeast
print southwest == new_southwest
print len(midwest) + len(southwest) + len(southeast)
# Out:
# midwest includes: ['AK', 'CO', 'CT', 'DC', 'DE', 'HI', 'IL', 'IN', 'KS', 'MD', 'ME', 'MI', 'MN', 'MT', 'ND', 'NE', 'NH', 'NJ', 'NY', 'OH', 'PA', 'RI', 'SD', 'UT', 'VA', 'WA', 'WI', 'WY']
# southeast includes: ['AL', 'AR', 'AZ', 'CA', 'FL', 'GA', 'ID', 'KY', 'LA', 'MO', 'MS', 'NC', 'NM', 'NV', 'OK', 'OR', 'SC', 'TN', 'TX', 'WV']
# southwest includes: ['IA', 'MA', 'VT']
# False
# False
# False
# 51

# %%
midwest = new_midwest
southwest = new_southwest
southeast = new_southeast
#west = ['AK', 'CA', 'CO', 'HI', 'ID', 'MT', 'NV', 'OR', 'UT', 'WA', 'WY']
#midwest = ['AK', 'CO', 'CT', 'DE', 'HI', 'IA', 'IL', 'IN', 'KS', 'MA', 'MD', 'ME', 'MI', 'MN', 'MT', 'ND', 'NE', 'NH', 'NY', 'OH', 'PA', 'RI', 'SD', 'UT', 'VA', 'VT', 'WA', 'WI', 'WY']
#southwest = ['MA', 'VT']
#southeast = ['AL', 'AR', 'AZ', 'CA', 'FL', 'GA', 'ID', 'KY', 'LA', 'MO', 'MS', 'NC', 'NM', 'NV', 'OK', 'OR', 'SC', 'TN', 'TX', 'WV']
#northeast = ['CT', 'DE', 'ME', 'MD', 'MA', 'NH', 'NH', 'NY', 'PA', 'RI', 'VT']
#west.sort()
midwest.sort()
southwest.sort()
southeast.sort()
#northeast.sort()
#west_coef, west_incept = 0, 0
midwest_coef, midwest_incept = 0, 0
southeast_coef, southeast_incept = 0, 0
#northeast_coef, northeast_incept = 0, 0
southwest_coef, southwest_incept = 0, 0
#westdata = dict()
midwestdata = dict()
southeastdata = dict()
#northeastdata = dict()
southwestdata = dict()
allstates = midwest + southeast + southwest
for state in allstates:
    #westdata[state] = 0
    midwestdata[state] = 0
    southeastdata[state] = 0
    #northeastdata[state] = 0
    southwestdata[state] = 0
#west_coef, west_incept = regs(west)
midwest_coef, midwest_incept = regs(midwest)
southwest_coef, southwest_incept = regs(southwest)
southeast_coef, southeast_incept = regs(southeast)
#northeast_coef, northeast_incept = regs(northeast)
for row in whole:
    if row[4] in westdata.keys():
#        westdata[row[4]] += abs(float(row[6]) * west_coef - float(row[8]) + west_incept) / math.sqrt(float(west_coef) ** 2 + 1)
        midwestdata[row[4]] += abs(float(row[6]) * midwest_coef - float(row[8]) + midwest_incept) / math.sqrt(float(midwest_coef) ** 2 + 1)
        southeastdata[row[4]] += abs(float(row[6]) * southeast_coef - float(row[8]) + southeast_incept) / math.sqrt(float(southeast_coef) ** 2 + 1)
#        northeastdata[row[4]] += abs(float(row[6]) * northeast_coef - float(row[8]) + northeast_incept) / math.sqrt(float(northeast_coef) ** 2 + 1)
        southwestdata[row[4]] += abs(float(row[6]) * southwest_coef - float(row[8]) + northeast_incept) / math.sqrt(float(southwest_coef) ** 2 + 1)
#new_west = []
new_midwest = []
new_southwest = []
#new_northeast = []
new_southeast = []
for key in westdata.keys():
    tmp = [midwestdata[key], southeastdata[key], southwestdata[key]]
    idx = tmp.index(min(tmp))
    if idx == 0:
        new_midwest.append(key)
    elif idx == 1:
        new_southeast.append(key)
    elif idx == 2:
        new_southwest.append(key)
#     elif idx == 3:
#         new_northwest.append(key)
#     else:
#         new_southwest.append(key)
#new_west.sort()
new_midwest.sort()
new_southwest.sort()
#new_northwest.sort()
new_southeast.sort()
# if (west == new_west and midwest == new_midwest and southeast == new_southeast and southwest == new_southwest and northeast == new_northwest):
#     flag = 0
# else:
#     west = new_west
#     midwest = new_midwest
#     southeast = new_southeast
#     southwest = new_southwest
#     northeast = new_northwest
#print "west includes:", new_west
print "midwest includes:", new_midwest
print "southeast includes:", new_southeast
#print "northeast includes:", new_northeast
print "southwest includes:", new_southwest
print midwest == new_midwest
print southeast == new_southeast
print southwest == new_southwest
print len(midwest) + len(southwest) + len(southeast)
# Out:
# midwest includes: ['AK', 'CO', 'CT', 'DC', 'DE', 'HI', 'IA', 'IL', 'IN', 'KS', 'MA', 'MD', 'ME', 'MN', 'MT', 'ND', 'NE', 'NH', 'NJ', 'NY', 'OH', 'PA', 'RI', 'SD', 'UT', 'VA', 'WA', 'WI', 'WY']
# southeast includes: ['AL', 'AR', 'AZ', 'CA', 'FL', 'GA', 'ID', 'KY', 'LA', 'MI', 'MO', 'MS', 'NC', 'NM', 'NV', 'OK', 'OR', 'SC', 'TN', 'TX', 'WV']
# southwest includes: ['VT']
# False
# False
# False
# 51

# %%
midwest = new_midwest
southwest = new_southwest
southeast = new_southeast
#west = ['AK', 'CA', 'CO', 'HI', 'ID', 'MT', 'NV', 'OR', 'UT', 'WA', 'WY']
#midwest = ['AK', 'CO', 'CT', 'DE', 'HI', 'IA', 'IL', 'IN', 'KS', 'MA', 'MD', 'ME', 'MI', 'MN', 'MT', 'ND', 'NE', 'NH', 'NY', 'OH', 'PA', 'RI', 'SD', 'UT', 'VA', 'VT', 'WA', 'WI', 'WY']
#southwest = ['MA', 'VT']
#southeast = ['AL', 'AR', 'AZ', 'CA', 'FL', 'GA', 'ID', 'KY', 'LA', 'MO', 'MS', 'NC', 'NM', 'NV', 'OK', 'OR', 'SC', 'TN', 'TX', 'WV']
#northeast = ['CT', 'DE', 'ME', 'MD', 'MA', 'NH', 'NH', 'NY', 'PA', 'RI', 'VT']
#west.sort()
midwest.sort()
southwest.sort()
southeast.sort()
#northeast.sort()
#west_coef, west_incept = 0, 0
midwest_coef, midwest_incept = 0, 0
southeast_coef, southeast_incept = 0, 0
#northeast_coef, northeast_incept = 0, 0
southwest_coef, southwest_incept = 0, 0
#westdata = dict()
midwestdata = dict()
southeastdata = dict()
#northeastdata = dict()
southwestdata = dict()
allstates = midwest + southeast + southwest
for state in allstates:
    #westdata[state] = 0
    midwestdata[state] = 0
    southeastdata[state] = 0
    #northeastdata[state] = 0
    southwestdata[state] = 0
#west_coef, west_incept = regs(west)
midwest_coef, midwest_incept = regs(midwest)
southwest_coef, southwest_incept = regs(southwest)
southeast_coef, southeast_incept = regs(southeast)
#northeast_coef, northeast_incept = regs(northeast)
for row in whole:
    if row[4] in westdata.keys():
#        westdata[row[4]] += abs(float(row[6]) * west_coef - float(row[8]) + west_incept) / math.sqrt(float(west_coef) ** 2 + 1)
        midwestdata[row[4]] += abs(float(row[6]) * midwest_coef - float(row[8]) + midwest_incept) / math.sqrt(float(midwest_coef) ** 2 + 1)
        southeastdata[row[4]] += abs(float(row[6]) * southeast_coef - float(row[8]) + southeast_incept) / math.sqrt(float(southeast_coef) ** 2 + 1)
#        northeastdata[row[4]] += abs(float(row[6]) * northeast_coef - float(row[8]) + northeast_incept) / math.sqrt(float(northeast_coef) ** 2 + 1)
        southwestdata[row[4]] += abs(float(row[6]) * southwest_coef - float(row[8]) + northeast_incept) / math.sqrt(float(southwest_coef) ** 2 + 1)
#new_west = []
new_midwest = []
new_southwest = []
#new_northeast = []
new_southeast = []
for key in westdata.keys():
    tmp = [midwestdata[key], southeastdata[key], southwestdata[key]]
    idx = tmp.index(min(tmp))
    if idx == 0:
        new_midwest.append(key)
    elif idx == 1:
        new_southeast.append(key)
    elif idx == 2:
        new_southwest.append(key)
#     elif idx == 3:
#         new_northwest.append(key)
#     else:
#         new_southwest.append(key)
#new_west.sort()
new_midwest.sort()
new_southwest.sort()
#new_northwest.sort()
new_southeast.sort()
# if (west == new_west and midwest == new_midwest and southeast == new_southeast and southwest == new_southwest and northeast == new_northwest):
#     flag = 0
# else:
#     west = new_west
#     midwest = new_midwest
#     southeast = new_southeast
#     southwest = new_southwest
#     northeast = new_northwest
#print "west includes:", new_west
print "midwest includes:", new_midwest
print "southeast includes:", new_southeast
#print "northeast includes:", new_northeast
print "southwest includes:", new_southwest
print midwest == new_midwest
print southeast == new_southeast
print southwest == new_southwest
print len(midwest) + len(southwest) + len(southeast)
# Out:
# midwest includes: ['IL', 'IN', 'KS', 'NJ', 'NY', 'OH']
# southeast includes: ['AL', 'AR', 'AZ', 'CA', 'FL', 'GA', 'ID', 'KY', 'LA', 'MI', 'MO', 'MS', 'NC', 'NM', 'NV', 'OK', 'OR', 'SC', 'TN', 'TX', 'WV']
# southwest includes: ['AK', 'CO', 'CT', 'DC', 'DE', 'HI', 'IA', 'MA', 'MD', 'ME', 'MN', 'MT', 'ND', 'NE', 'NH', 'PA', 'RI', 'SD', 'UT', 'VA', 'VT', 'WA', 'WI', 'WY']
# False
# True
# False
# 51

# %%
midwest = new_midwest
southwest = new_southwest
southeast = new_southeast
#west = ['AK', 'CA', 'CO', 'HI', 'ID', 'MT', 'NV', 'OR', 'UT', 'WA', 'WY']
#midwest = ['AK', 'CO', 'CT', 'DE', 'HI', 'IA', 'IL', 'IN', 'KS', 'MA', 'MD', 'ME', 'MI', 'MN', 'MT', 'ND', 'NE', 'NH', 'NY', 'OH', 'PA', 'RI', 'SD', 'UT', 'VA', 'VT', 'WA', 'WI', 'WY']
#southwest = ['MA', 'VT']
#southeast = ['AL', 'AR', 'AZ', 'CA', 'FL', 'GA', 'ID', 'KY', 'LA', 'MO', 'MS', 'NC', 'NM', 'NV', 'OK', 'OR', 'SC', 'TN', 'TX', 'WV']
#northeast = ['CT', 'DE', 'ME', 'MD', 'MA', 'NH', 'NH', 'NY', 'PA', 'RI', 'VT']
#west.sort()
midwest.sort()
southwest.sort()
southeast.sort()
#northeast.sort()
#west_coef, west_incept = 0, 0
midwest_coef, midwest_incept = 0, 0
southeast_coef, southeast_incept = 0, 0
#northeast_coef, northeast_incept = 0, 0
southwest_coef, southwest_incept = 0, 0
#westdata = dict()
midwestdata = dict()
southeastdata = dict()
#northeastdata = dict()
southwestdata = dict()
allstates = midwest + southeast + southwest
for state in allstates:
    #westdata[state] = 0
    midwestdata[state] = 0
    southeastdata[state] = 0
    #northeastdata[state] = 0
    southwestdata[state] = 0
#west_coef, west_incept = regs(west)
midwest_coef, midwest_incept = regs(midwest)
southwest_coef, southwest_incept = regs(southwest)
southeast_coef, southeast_incept = regs(southeast)
#northeast_coef, northeast_incept = regs(northeast)
for row in whole:
    if row[4] in westdata.keys():
#        westdata[row[4]] += abs(float(row[6]) * west_coef - float(row[8]) + west_incept) / math.sqrt(float(west_coef) ** 2 + 1)
        midwestdata[row[4]] += abs(float(row[6]) * midwest_coef - float(row[8]) + midwest_incept) / math.sqrt(float(midwest_coef) ** 2 + 1)
        southeastdata[row[4]] += abs(float(row[6]) * southeast_coef - float(row[8]) + southeast_incept) / math.sqrt(float(southeast_coef) ** 2 + 1)
#        northeastdata[row[4]] += abs(float(row[6]) * northeast_coef - float(row[8]) + northeast_incept) / math.sqrt(float(northeast_coef) ** 2 + 1)
        southwestdata[row[4]] += abs(float(row[6]) * southwest_coef - float(row[8]) + northeast_incept) / math.sqrt(float(southwest_coef) ** 2 + 1)
#new_west = []
new_midwest = []
new_southwest = []
#new_northeast = []
new_southeast = []
for key in westdata.keys():
    tmp = [midwestdata[key], southeastdata[key], southwestdata[key]]
    idx = tmp.index(min(tmp))
    if idx == 0:
        new_midwest.append(key)
    elif idx == 1:
        new_southeast.append(key)
    elif idx == 2:
        new_southwest.append(key)
#     elif idx == 3:
#         new_northwest.append(key)
#     else:
#         new_southwest.append(key)
#new_west.sort()
new_midwest.sort()
new_southwest.sort()
#new_northwest.sort()
new_southeast.sort()
# if (west == new_west and midwest == new_midwest and southeast == new_southeast and southwest == new_southwest and northeast == new_northwest):
#     flag = 0
# else:
#     west = new_west
#     midwest = new_midwest
#     southeast = new_southeast
#     southwest = new_southwest
#     northeast = new_northwest
#print "west includes:", new_west
print "midwest includes:", new_midwest
print "southeast includes:", new_southeast
#print "northeast includes:", new_northeast
print "southwest includes:", new_southwest
print midwest == new_midwest
print southeast == new_southeast
print southwest == new_southwest
print len(midwest) + len(southwest) + len(southeast)
# Out:
# midwest includes: ['AK', 'CO', 'HI', 'IL', 'IN', 'KS', 'ME', 'MI', 'MT', 'NJ', 'NY', 'OH', 'PA', 'SD', 'VA', 'WA', 'WY']
# southeast includes: ['AL', 'AR', 'AZ', 'CA', 'FL', 'GA', 'ID', 'KY', 'LA', 'MO', 'MS', 'NC', 'NM', 'NV', 'OK', 'OR', 'SC', 'TN', 'TX', 'WV']
# southwest includes: ['CT', 'DC', 'DE', 'IA', 'MA', 'MD', 'MN', 'ND', 'NE', 'NH', 'RI', 'UT', 'VT', 'WI']
# False
# False
# False
# 51

# %%
midwest = new_midwest
southwest = new_southwest
southeast = new_southeast
#west = ['AK', 'CA', 'CO', 'HI', 'ID', 'MT', 'NV', 'OR', 'UT', 'WA', 'WY']
#midwest = ['AK', 'CO', 'CT', 'DE', 'HI', 'IA', 'IL', 'IN', 'KS', 'MA', 'MD', 'ME', 'MI', 'MN', 'MT', 'ND', 'NE', 'NH', 'NY', 'OH', 'PA', 'RI', 'SD', 'UT', 'VA', 'VT', 'WA', 'WI', 'WY']
#southwest = ['MA', 'VT']
#southeast = ['AL', 'AR', 'AZ', 'CA', 'FL', 'GA', 'ID', 'KY', 'LA', 'MO', 'MS', 'NC', 'NM', 'NV', 'OK', 'OR', 'SC', 'TN', 'TX', 'WV']
#northeast = ['CT', 'DE', 'ME', 'MD', 'MA', 'NH', 'NH', 'NY', 'PA', 'RI', 'VT']
#west.sort()
midwest.sort()
southwest.sort()
southeast.sort()
#northeast.sort()
#west_coef, west_incept = 0, 0
midwest_coef, midwest_incept = 0, 0
southeast_coef, southeast_incept = 0, 0
#northeast_coef, northeast_incept = 0, 0
southwest_coef, southwest_incept = 0, 0
#westdata = dict()
midwestdata = dict()
southeastdata = dict()
#northeastdata = dict()
southwestdata = dict()
allstates = midwest + southeast + southwest
for state in allstates:
    #westdata[state] = 0
    midwestdata[state] = 0
    southeastdata[state] = 0
    #northeastdata[state] = 0
    southwestdata[state] = 0
#west_coef, west_incept = regs(west)
midwest_coef, midwest_incept = regs(midwest)
southwest_coef, southwest_incept = regs(southwest)
southeast_coef, southeast_incept = regs(southeast)
#northeast_coef, northeast_incept = regs(northeast)
for row in whole:
    if row[4] in westdata.keys():
#        westdata[row[4]] += abs(float(row[6]) * west_coef - float(row[8]) + west_incept) / math.sqrt(float(west_coef) ** 2 + 1)
        midwestdata[row[4]] += abs(float(row[6]) * midwest_coef - float(row[8]) + midwest_incept) / math.sqrt(float(midwest_coef) ** 2 + 1)
        southeastdata[row[4]] += abs(float(row[6]) * southeast_coef - float(row[8]) + southeast_incept) / math.sqrt(float(southeast_coef) ** 2 + 1)
#        northeastdata[row[4]] += abs(float(row[6]) * northeast_coef - float(row[8]) + northeast_incept) / math.sqrt(float(northeast_coef) ** 2 + 1)
        southwestdata[row[4]] += abs(float(row[6]) * southwest_coef - float(row[8]) + northeast_incept) / math.sqrt(float(southwest_coef) ** 2 + 1)
#new_west = []
new_midwest = []
new_southwest = []
#new_northeast = []
new_southeast = []
for key in westdata.keys():
    tmp = [midwestdata[key], southeastdata[key], southwestdata[key]]
    idx = tmp.index(min(tmp))
    if idx == 0:
        new_midwest.append(key)
    elif idx == 1:
        new_southeast.append(key)
    elif idx == 2:
        new_southwest.append(key)
#     elif idx == 3:
#         new_northwest.append(key)
#     else:
#         new_southwest.append(key)
#new_west.sort()
new_midwest.sort()
new_southwest.sort()
#new_northwest.sort()
new_southeast.sort()
# if (west == new_west and midwest == new_midwest and southeast == new_southeast and southwest == new_southwest and northeast == new_northwest):
#     flag = 0
# else:
#     west = new_west
#     midwest = new_midwest
#     southeast = new_southeast
#     southwest = new_southwest
#     northeast = new_northwest
#print "west includes:", new_west
print "midwest includes:", new_midwest
print "southeast includes:", new_southeast
#print "northeast includes:", new_northeast
print "southwest includes:", new_southwest
print midwest == new_midwest
print southeast == new_southeast
print southwest == new_southwest
print len(midwest) + len(southwest) + len(southeast)
# Out:
# midwest includes: ['AK', 'CO', 'DC', 'DE', 'HI', 'IL', 'IN', 'KS', 'MD', 'ME', 'MI', 'MN', 'MO', 'MT', 'ND', 'NJ', 'NY', 'OH', 'PA', 'SD', 'UT', 'VA', 'WA', 'WY']
# southeast includes: ['AL', 'AR', 'AZ', 'CA', 'FL', 'GA', 'ID', 'KY', 'LA', 'MS', 'NC', 'NM', 'NV', 'OK', 'OR', 'SC', 'TN', 'TX', 'WV']
# southwest includes: ['CT', 'IA', 'MA', 'NE', 'NH', 'RI', 'VT', 'WI']
# False
# False
# False
# 51

# %%
midwest = new_midwest
southwest = new_southwest
southeast = new_southeast
#west = ['AK', 'CA', 'CO', 'HI', 'ID', 'MT', 'NV', 'OR', 'UT', 'WA', 'WY']
#midwest = ['AK', 'CO', 'CT', 'DE', 'HI', 'IA', 'IL', 'IN', 'KS', 'MA', 'MD', 'ME', 'MI', 'MN', 'MT', 'ND', 'NE', 'NH', 'NY', 'OH', 'PA', 'RI', 'SD', 'UT', 'VA', 'VT', 'WA', 'WI', 'WY']
#southwest = ['MA', 'VT']
#southeast = ['AL', 'AR', 'AZ', 'CA', 'FL', 'GA', 'ID', 'KY', 'LA', 'MO', 'MS', 'NC', 'NM', 'NV', 'OK', 'OR', 'SC', 'TN', 'TX', 'WV']
#northeast = ['CT', 'DE', 'ME', 'MD', 'MA', 'NH', 'NH', 'NY', 'PA', 'RI', 'VT']
#west.sort()
midwest.sort()
southwest.sort()
southeast.sort()
#northeast.sort()
#west_coef, west_incept = 0, 0
midwest_coef, midwest_incept = 0, 0
southeast_coef, southeast_incept = 0, 0
#northeast_coef, northeast_incept = 0, 0
southwest_coef, southwest_incept = 0, 0
#westdata = dict()
midwestdata = dict()
southeastdata = dict()
#northeastdata = dict()
southwestdata = dict()
allstates = midwest + southeast + southwest
for state in allstates:
    #westdata[state] = 0
    midwestdata[state] = 0
    southeastdata[state] = 0
    #northeastdata[state] = 0
    southwestdata[state] = 0
#west_coef, west_incept = regs(west)
midwest_coef, midwest_incept = regs(midwest)
southwest_coef, southwest_incept = regs(southwest)
southeast_coef, southeast_incept = regs(southeast)
#northeast_coef, northeast_incept = regs(northeast)
for row in whole:
    if row[4] in westdata.keys():
#        westdata[row[4]] += abs(float(row[6]) * west_coef - float(row[8]) + west_incept) / math.sqrt(float(west_coef) ** 2 + 1)
        midwestdata[row[4]] += abs(float(row[6]) * midwest_coef - float(row[8]) + midwest_incept) / math.sqrt(float(midwest_coef) ** 2 + 1)
        southeastdata[row[4]] += abs(float(row[6]) * southeast_coef - float(row[8]) + southeast_incept) / math.sqrt(float(southeast_coef) ** 2 + 1)
#        northeastdata[row[4]] += abs(float(row[6]) * northeast_coef - float(row[8]) + northeast_incept) / math.sqrt(float(northeast_coef) ** 2 + 1)
        southwestdata[row[4]] += abs(float(row[6]) * southwest_coef - float(row[8]) + northeast_incept) / math.sqrt(float(southwest_coef) ** 2 + 1)
#new_west = []
new_midwest = []
new_southwest = []
#new_northeast = []
new_southeast = []
for key in westdata.keys():
    tmp = [midwestdata[key], southeastdata[key], southwestdata[key]]
    idx = tmp.index(min(tmp))
    if idx == 0:
        new_midwest.append(key)
    elif idx == 1:
        new_southeast.append(key)
    elif idx == 2:
        new_southwest.append(key)
#     elif idx == 3:
#         new_northwest.append(key)
#     else:
#         new_southwest.append(key)
#new_west.sort()
new_midwest.sort()
new_southwest.sort()
#new_northwest.sort()
new_southeast.sort()
# if (west == new_west and midwest == new_midwest and southeast == new_southeast and southwest == new_southwest and northeast == new_northwest):
#     flag = 0
# else:
#     west = new_west
#     midwest = new_midwest
#     southeast = new_southeast
#     southwest = new_southwest
#     northeast = new_northwest
#print "west includes:", new_west
print "midwest includes:", new_midwest
print "southeast includes:", new_southeast
#print "northeast includes:", new_northeast
print "southwest includes:", new_southwest
print midwest == new_midwest
print southeast == new_southeast
print southwest == new_southwest
print len(midwest) + len(southwest) + len(southeast)
# Out:
# midwest includes: ['AK', 'CO', 'CT', 'DC', 'DE', 'HI', 'IL', 'IN', 'KS', 'MD', 'ME', 'MI', 'MN', 'MT', 'ND', 'NE', 'NH', 'NJ', 'NY', 'OH', 'PA', 'RI', 'SD', 'UT', 'VA', 'WA', 'WI', 'WY']
# southeast includes: ['AL', 'AR', 'AZ', 'CA', 'FL', 'GA', 'ID', 'KY', 'LA', 'MO', 'MS', 'NC', 'NM', 'NV', 'OK', 'OR', 'SC', 'TN', 'TX', 'WV']
# southwest includes: ['IA', 'MA', 'VT']
# False
# False
# False
# 51

# %%
midwest = new_midwest
southwest = new_southwest
southeast = new_southeast
#west = ['AK', 'CA', 'CO', 'HI', 'ID', 'MT', 'NV', 'OR', 'UT', 'WA', 'WY']
#midwest = ['AK', 'CO', 'CT', 'DE', 'HI', 'IA', 'IL', 'IN', 'KS', 'MA', 'MD', 'ME', 'MI', 'MN', 'MT', 'ND', 'NE', 'NH', 'NY', 'OH', 'PA', 'RI', 'SD', 'UT', 'VA', 'VT', 'WA', 'WI', 'WY']
#southwest = ['MA', 'VT']
#southeast = ['AL', 'AR', 'AZ', 'CA', 'FL', 'GA', 'ID', 'KY', 'LA', 'MO', 'MS', 'NC', 'NM', 'NV', 'OK', 'OR', 'SC', 'TN', 'TX', 'WV']
#northeast = ['CT', 'DE', 'ME', 'MD', 'MA', 'NH', 'NH', 'NY', 'PA', 'RI', 'VT']
#west.sort()
midwest.sort()
southwest.sort()
southeast.sort()
#northeast.sort()
#west_coef, west_incept = 0, 0
midwest_coef, midwest_incept = 0, 0
southeast_coef, southeast_incept = 0, 0
#northeast_coef, northeast_incept = 0, 0
southwest_coef, southwest_incept = 0, 0
#westdata = dict()
midwestdata = dict()
southeastdata = dict()
#northeastdata = dict()
southwestdata = dict()
allstates = midwest + southeast + southwest
for state in allstates:
    #westdata[state] = 0
    midwestdata[state] = 0
    southeastdata[state] = 0
    #northeastdata[state] = 0
    southwestdata[state] = 0
#west_coef, west_incept = regs(west)
midwest_coef, midwest_incept = regs(midwest)
southwest_coef, southwest_incept = regs(southwest)
southeast_coef, southeast_incept = regs(southeast)
#northeast_coef, northeast_incept = regs(northeast)
for row in whole:
    if row[4] in westdata.keys():
#        westdata[row[4]] += abs(float(row[6]) * west_coef - float(row[8]) + west_incept) / math.sqrt(float(west_coef) ** 2 + 1)
        midwestdata[row[4]] += abs(float(row[6]) * midwest_coef - float(row[8]) + midwest_incept) / math.sqrt(float(midwest_coef) ** 2 + 1)
        southeastdata[row[4]] += abs(float(row[6]) * southeast_coef - float(row[8]) + southeast_incept) / math.sqrt(float(southeast_coef) ** 2 + 1)
#        northeastdata[row[4]] += abs(float(row[6]) * northeast_coef - float(row[8]) + northeast_incept) / math.sqrt(float(northeast_coef) ** 2 + 1)
        southwestdata[row[4]] += abs(float(row[6]) * southwest_coef - float(row[8]) + northeast_incept) / math.sqrt(float(southwest_coef) ** 2 + 1)
#new_west = []
new_midwest = []
new_southwest = []
#new_northeast = []
new_southeast = []
for key in westdata.keys():
    tmp = [midwestdata[key], southeastdata[key], southwestdata[key]]
    idx = tmp.index(min(tmp))
    if idx == 0:
        new_midwest.append(key)
    elif idx == 1:
        new_southeast.append(key)
    elif idx == 2:
        new_southwest.append(key)
#     elif idx == 3:
#         new_northwest.append(key)
#     else:
#         new_southwest.append(key)
#new_west.sort()
new_midwest.sort()
new_southwest.sort()
#new_northwest.sort()
new_southeast.sort()
# if (west == new_west and midwest == new_midwest and southeast == new_southeast and southwest == new_southwest and northeast == new_northwest):
#     flag = 0
# else:
#     west = new_west
#     midwest = new_midwest
#     southeast = new_southeast
#     southwest = new_southwest
#     northeast = new_northwest
#print "west includes:", new_west
print "midwest includes:", new_midwest
print "southeast includes:", new_southeast
#print "northeast includes:", new_northeast
print "southwest includes:", new_southwest
print midwest == new_midwest
print southeast == new_southeast
print southwest == new_southwest
print len(midwest) + len(southwest) + len(southeast)
# Out:
# midwest includes: ['AK', 'CO', 'CT', 'DC', 'DE', 'HI', 'IA', 'IL', 'IN', 'KS', 'MA', 'MD', 'ME', 'MN', 'MT', 'ND', 'NE', 'NH', 'NJ', 'NY', 'OH', 'PA', 'RI', 'SD', 'UT', 'VA', 'WA', 'WI', 'WY']
# southeast includes: ['AL', 'AR', 'AZ', 'CA', 'FL', 'GA', 'ID', 'KY', 'LA', 'MI', 'MO', 'MS', 'NC', 'NM', 'NV', 'OK', 'OR', 'SC', 'TN', 'TX', 'WV']
# southwest includes: ['VT']
# False
# False
# False
# 51

# %%
midwest = new_midwest
southwest = new_southwest
southeast = new_southeast
#west = ['AK', 'CA', 'CO', 'HI', 'ID', 'MT', 'NV', 'OR', 'UT', 'WA', 'WY']
#midwest = ['AK', 'CO', 'CT', 'DE', 'HI', 'IA', 'IL', 'IN', 'KS', 'MA', 'MD', 'ME', 'MI', 'MN', 'MT', 'ND', 'NE', 'NH', 'NY', 'OH', 'PA', 'RI', 'SD', 'UT', 'VA', 'VT', 'WA', 'WI', 'WY']
#southwest = ['MA', 'VT']
#southeast = ['AL', 'AR', 'AZ', 'CA', 'FL', 'GA', 'ID', 'KY', 'LA', 'MO', 'MS', 'NC', 'NM', 'NV', 'OK', 'OR', 'SC', 'TN', 'TX', 'WV']
#northeast = ['CT', 'DE', 'ME', 'MD', 'MA', 'NH', 'NH', 'NY', 'PA', 'RI', 'VT']
#west.sort()
midwest.sort()
southwest.sort()
southeast.sort()
#northeast.sort()
#west_coef, west_incept = 0, 0
midwest_coef, midwest_incept = 0, 0
southeast_coef, southeast_incept = 0, 0
#northeast_coef, northeast_incept = 0, 0
southwest_coef, southwest_incept = 0, 0
#westdata = dict()
midwestdata = dict()
southeastdata = dict()
#northeastdata = dict()
southwestdata = dict()
allstates = midwest + southeast + southwest
for state in allstates:
    #westdata[state] = 0
    midwestdata[state] = 0
    southeastdata[state] = 0
    #northeastdata[state] = 0
    southwestdata[state] = 0
#west_coef, west_incept = regs(west)
midwest_coef, midwest_incept = regs(midwest)
southwest_coef, southwest_incept = regs(southwest)
southeast_coef, southeast_incept = regs(southeast)
#northeast_coef, northeast_incept = regs(northeast)
for row in whole:
    if row[4] in westdata.keys():
#        westdata[row[4]] += abs(float(row[6]) * west_coef - float(row[8]) + west_incept) / math.sqrt(float(west_coef) ** 2 + 1)
        midwestdata[row[4]] += abs(float(row[6]) * midwest_coef - float(row[8]) + midwest_incept) / math.sqrt(float(midwest_coef) ** 2 + 1)
        southeastdata[row[4]] += abs(float(row[6]) * southeast_coef - float(row[8]) + southeast_incept) / math.sqrt(float(southeast_coef) ** 2 + 1)
#        northeastdata[row[4]] += abs(float(row[6]) * northeast_coef - float(row[8]) + northeast_incept) / math.sqrt(float(northeast_coef) ** 2 + 1)
        southwestdata[row[4]] += abs(float(row[6]) * southwest_coef - float(row[8]) + northeast_incept) / math.sqrt(float(southwest_coef) ** 2 + 1)
#new_west = []
new_midwest = []
new_southwest = []
#new_northeast = []
new_southeast = []
for key in westdata.keys():
    tmp = [midwestdata[key], southeastdata[key], southwestdata[key]]
    idx = tmp.index(min(tmp))
    if idx == 0:
        new_midwest.append(key)
    elif idx == 1:
        new_southeast.append(key)
    elif idx == 2:
        new_southwest.append(key)
#     elif idx == 3:
#         new_northwest.append(key)
#     else:
#         new_southwest.append(key)
#new_west.sort()
new_midwest.sort()
new_southwest.sort()
#new_northwest.sort()
new_southeast.sort()
# if (west == new_west and midwest == new_midwest and southeast == new_southeast and southwest == new_southwest and northeast == new_northwest):
#     flag = 0
# else:
#     west = new_west
#     midwest = new_midwest
#     southeast = new_southeast
#     southwest = new_southwest
#     northeast = new_northwest
#print "west includes:", new_west
print "midwest includes:", new_midwest
print "southeast includes:", new_southeast
#print "northeast includes:", new_northeast
print "southwest includes:", new_southwest
print midwest == new_midwest
print southeast == new_southeast
print southwest == new_southwest
print len(midwest) + len(southwest) + len(southeast)
# Out:
# midwest includes: ['AK', 'CO', 'DC', 'DE', 'HI', 'IL', 'IN', 'KS', 'MD', 'ME', 'MI', 'MN', 'MO', 'MT', 'ND', 'NJ', 'NY', 'OH', 'PA', 'SD', 'UT', 'VA', 'WA', 'WY']
# southeast includes: ['AL', 'AR', 'AZ', 'CA', 'FL', 'GA', 'ID', 'KY', 'LA', 'MS', 'NC', 'NM', 'NV', 'OK', 'OR', 'SC', 'TN', 'TX', 'WV']
# southwest includes: ['CT', 'IA', 'MA', 'NE', 'NH', 'RI', 'VT', 'WI']
# False
# False
# False
# 51

# %%
print midwest
print southwest
print southeast
# Out:
# ['IL', 'IN', 'KS', 'NJ', 'NY', 'OH']
# ['AK', 'CO', 'CT', 'DC', 'DE', 'HI', 'IA', 'MA', 'MD', 'ME', 'MN', 'MT', 'ND', 'NE', 'NH', 'PA', 'RI', 'SD', 'UT', 'VA', 'VT', 'WA', 'WI', 'WY']
# ['AL', 'AR', 'AZ', 'CA', 'FL', 'GA', 'ID', 'KY', 'LA', 'MI', 'MO', 'MS', 'NC', 'NM', 'NV', 'OK', 'OR', 'SC', 'TN', 'TX', 'WV']

# %%
for i in range(100):
    midwest.sort()
    southwest.sort()
    southeast.sort()
    midwest_coef, midwest_incept = 0, 0
    southeast_coef, southeast_incept = 0, 0
    southwest_coef, southwest_incept = 0, 0
    midwestdata = dict()
    southeastdata = dict()
    southwestdata = dict()
    allstates = midwest + southeast + southwest
    for state in allstates:
        midwestdata[state] = 0
        southeastdata[state] = 0
        southwestdata[state] = 0
    midwest_coef, midwest_incept = regs(midwest)
    southwest_coef, southwest_incept = regs(southwest)
    southeast_coef, southeast_incept = regs(southeast)
    for row in whole:
        if row[4] in westdata.keys():
            midwestdata[row[4]] += abs(float(row[6]) * midwest_coef - float(row[8]) + midwest_incept) / math.sqrt(float(midwest_coef) ** 2 + 1)
            southeastdata[row[4]] += abs(float(row[6]) * southeast_coef - float(row[8]) + southeast_incept) / math.sqrt(float(southeast_coef) ** 2 + 1)
            southwestdata[row[4]] += abs(float(row[6]) * southwest_coef - float(row[8]) + northeast_incept) / math.sqrt(float(southwest_coef) ** 2 + 1)
    new_midwest = []
    new_southwest = []
    new_southeast = []
    for key in westdata.keys():
        tmp = [midwestdata[key], southeastdata[key], southwestdata[key]]
        idx = tmp.index(min(tmp))
        if idx == 0:
            new_midwest.append(key)
        elif idx == 1:
            new_southeast.append(key)
        elif idx == 2:
            new_southwest.append(key)
    new_midwest.sort()
    new_southwest.sort()
    new_southeast.sort()
    if (midwest == new_midwest and southeast == new_southeast and southwest == new_southwest):
        print 1
        break
    midwest = new_midwest
    southeast = new_southeast
    southwest = new_southwest
print "midwest includes:", midwest
print "southeast includes:", southeast
print "southwest includes:", southwest
# Out:
# midwest includes: ['IL', 'IN', 'KS', 'NJ', 'NY', 'OH']
# southeast includes: ['AL', 'AR', 'AZ', 'CA', 'FL', 'GA', 'ID', 'KY', 'LA', 'MI', 'MO', 'MS', 'NC', 'NM', 'NV', 'OK', 'OR', 'SC', 'TN', 'TX', 'WV']
# southwest includes: ['AK', 'CO', 'CT', 'DC', 'DE', 'HI', 'IA', 'MA', 'MD', 'ME', 'MN', 'MT', 'ND', 'NE', 'NH', 'PA', 'RI', 'SD', 'UT', 'VA', 'VT', 'WA', 'WI', 'WY']

# %%
west = ['CA', 'MI', 'MO', 'MT', 'NV', 'VA']
midwest = ['CO', 'DE', 'HI', 'IL', 'IN', 'KS', 'ME', 'ND', 'NY', 'OH', 'PA', 'SD', 'WA']
southeast = ['AL', 'AR', 'AZ', 'GA', 'KY', 'LA', 'MS', 'NM', 'SC', 'TN']
northeast = ['AK', 'CT', 'IA', 'MA', 'MD', 'MN', 'NE', 'NH', 'NJ', 'RI', 'UT', 'VT', 'WI', 'WY']
southwest = ['FL', 'ID', 'NC', 'OK', 'OR', 'TX', 'WV']

# %%
charge_west = []
poverty_west = []
for i in range(1, len(whole)):
    if whole[i][7] != 'what' and whole[i][4] in west:
        charge_west.append([float(whole[i][6])])
        poverty_west.append(float(whole[i][8]))

regr = linear_model.LinearRegression()
regr.fit(charge_west, poverty_west)
print("Mean squared error: %.2f"
       % np.mean((regr.predict(charge_west) - poverty_west) ** 2))
print('Variance score: %.2f' % regr.score(charge_west, poverty_west))
plt.scatter(charge_west, poverty_west,  color='black')
plt.plot(charge_west, regr.predict(charge_west), color='blue',
         linewidth=3)
plt.xticks()
plt.yticks()
plt.xlim([0, 5])
plt.ylim([0, 40])
plt.title("Group 1 \n K-means")
#plt.title("K-means")
plt.xlabel("Weighted Charge")
plt.ylabel("Weighted Poverty Rate")
plt.show()
# Out:
# Mean squared error: 10.13
# Variance score: 0.02

# %%
charge_midwest = []
poverty_midwest = []
for i in range(1, len(whole)):
    if whole[i][7] != 'what' and whole[i][4] in midwest:
        charge_midwest.append([float(whole[i][6])])
        poverty_midwest.append(float(whole[i][8]))

regr = linear_model.LinearRegression()
regr.fit(charge_midwest, poverty_midwest)
print("Mean squared error: %.2f"
       % np.mean((regr.predict(charge_midwest) - poverty_midwest) ** 2))
print('Variance score: %.2f' % regr.score(charge_midwest, poverty_midwest))
plt.scatter(charge_midwest, poverty_midwest,  color='black')
plt.plot(charge_midwest, regr.predict(charge_midwest), color='blue',
         linewidth=3)
plt.xticks()
plt.yticks()
plt.xlim([0, 5])
plt.ylim([0, 40])
plt.title("Group 2 \n K-means")
#plt.title("K-means")
plt.xlabel("Weighted Charge")
plt.ylabel("Weighted Poverty Rate")
plt.show()
# Out:
# Mean squared error: 4.93
# Variance score: 0.13

# %%
charge_southeast = []
poverty_southeast = []
for i in range(1, len(whole)):
    if whole[i][7] != 'what' and whole[i][4] in southeast:
        charge_southeast.append([float(whole[i][6])])
        poverty_southeast.append(float(whole[i][8]))

regr = linear_model.LinearRegression()
regr.fit(charge_southeast, poverty_southeast)
print("Mean squared error: %.2f"
       % np.mean((regr.predict(charge_southeast) - poverty_southeast) ** 2))
print('Variance score: %.2f' % regr.score(charge_southeast, poverty_southeast))
plt.scatter(charge_southeast, poverty_southeast,  color='black')
plt.plot(charge_southeast, regr.predict(charge_southeast), color='blue',
         linewidth=3)
plt.xticks()
plt.yticks()
plt.xlim([0, 5])
plt.ylim([0, 40])
plt.title("Group 3 \n K-means")
#plt.title("K-means")
plt.xlabel("Weighted Charge")
plt.ylabel("Weighted Poverty Rate")
plt.show()
# Out:
# Mean squared error: 14.84
# Variance score: 0.06

# %%
charge_northeast = []
poverty_northeast = []
for i in range(1, len(whole)):
    if whole[i][7] != 'what' and whole[i][4] in northeast:
        charge_northeast.append([float(whole[i][6])])
        poverty_northeast.append(float(whole[i][8]))

regr = linear_model.LinearRegression()
regr.fit(charge_northeast, poverty_northeast)
print("Mean squared error: %.2f"
       % np.mean((regr.predict(charge_northeast) - poverty_northeast) ** 2))
print('Variance score: %.2f' % regr.score(charge_northeast, poverty_northeast))
plt.scatter(charge_northeast, poverty_northeast,  color='black')
plt.plot(charge_northeast, regr.predict(charge_northeast), color='blue',
         linewidth=3)
plt.xticks()
plt.yticks()
plt.xlim([0, 5])
plt.ylim([0, 40])
plt.title("Group 4 \n K-means")
#plt.title("K-means")
plt.xlabel("Weighted Charge")
plt.ylabel("Weighted Poverty Rate")
plt.show()
# Out:
# Mean squared error: 3.15
# Variance score: 0.00

# %%
charge_southwest = []
poverty_southwest = []
for i in range(1, len(whole)):
    if whole[i][7] != 'what' and whole[i][4] in southwest:
        charge_southwest.append([float(whole[i][6])])
        poverty_southwest.append(float(whole[i][8]))

regr = linear_model.LinearRegression()
regr.fit(charge_southwest, poverty_southwest)
print("Mean squared error: %.2f"
       % np.mean((regr.predict(charge_southwest) - poverty_southwest) ** 2))
print('Variance score: %.2f' % regr.score(charge_southwest, poverty_southwest))
plt.scatter(charge_southwest, poverty_southwest,  color='black')
plt.plot(charge_southwest, regr.predict(charge_southwest), color='blue',
         linewidth=3)
plt.xticks()
plt.yticks()
plt.xlim([0, 5])
plt.ylim([0, 40])
plt.title("Group 5 \n K-means")
#plt.title("K-means")
plt.xlabel("Weighted Charge")
plt.ylabel("Weighted Poverty Rate")
plt.show()
# Out:
# Mean squared error: 14.98
# Variance score: 0.01
